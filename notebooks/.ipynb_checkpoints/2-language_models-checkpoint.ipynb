# %% [markdown]
# # Assignment #2: Language models

# %% [markdown]
# ## Objectives

# %% [markdown]
# The objectives of this assignment are to:
# * Write a program to find n-gram statistics
# * Compute the probability of a sentence
# * Know what a language model is
# * Write a short report of 1 to 2 pages on the assignment
# * Optionally read a short article on the importance of corpora

# %% [markdown]
# ## Submission

# %% [markdown]
# Once you have written all the missing code and run all the cells, you will submit your notebook to an automatic marking system. Do not erase the content of the cells as we will possibly check your programs manually.
# The submission instructions are at the bottom of the notebook.

# %% [markdown]
# ## Organization

# %% [markdown]
# * Each group will have to write Python programs to count unigrams, bigrams, and trigrams in a corpus of approximately one million words and to determine the probability of a sentence.
# * You can test you regular expression using the regex101.com site
# * Each student will have to write a short report of one to two pages and comment briefly the results. In your report, you must produce the tabulated results of your analysis as described below.

# %% [markdown]
# ## Programming

# %% [markdown]
# ### Imports

# %% [markdown]
# Some imports you may need. Add others as needed.

# %%
import bz2
import math
import os
import regex as re
import requests
import sys
from zipfile import ZipFile

# %% [markdown]
# ### Collecting and analyzing a corpus

# %% [markdown]
# Retrieve a corpus of novels by Selma Lagerl&ouml;f from this URL:
# <a href="https://github.com/pnugues/ilppp/blob/master/programs/corpus/Selma.txt">
#     <tt>https://github.com/pnugues/ilppp/blob/master/programs/corpus/Selma.txt</tt>
# </a>. The text of these novels was extracted
# from <a href="https://litteraturbanken.se/forfattare/LagerlofS/titlar">Lagerlöf arkivet</a> at
# <a href="https://litteraturbanken.se/">Litteraturbanken</a>.

# %%
# You may have to adjust the path
corpus = open('Selma.txt', encoding='utf8').read()

# %% [markdown]
# Run the <a href="https://github.com/pnugues/ilppp/tree/master/programs/ch02/python">concordance
# program </a> to print the lines containing a specific word, for instance <i>Nils</i>.

# %%
pattern = 'Nils Holgersson'
width = 25

# %%
# spaces match tabs and newlines
pattern = re.sub(' ', '\\s+', pattern)
# Replaces newlines with spaces in the text
clean_corpus = re.sub('\s+', ' ', corpus)
concordance = ('(.{{0,{width}}}{pattern}.{{0,{width}}})'
               .format(pattern=pattern, width=width))
for match in re.finditer(concordance, clean_corpus):
    print(match.group(1))
# print the string with 0..width characters on either side
# Out:
# Selma Lagerlöf Nils Holgerssons underbara resa genom Sv
# ! Se på Tummetott! Se på Nils Holgersson Tummetott!» Genast vände
# r,» sade han. »Jag heter Nils Holgersson och är son till en husma
# lden. »Inte är det värt, Nils Holgersson, att du är ängslig eller
#  i dem. På den tiden, då Nils Holgersson drog omkring med vildgäs
# ulle allt visa honom vad Nils Holgersson från Västra Vemmenhög va
# om ägde rum det året, då Nils Holgersson for omkring med vildgäss
# m vad det kan kosta dem. Nils Holgersson hade inte haft förstånd
# de det inte mer sägas om Nils Holgersson, att han inte tyckte om
#  Rosenbom?» För där stod Nils Holgersson mitt uppe på Rosenboms n
#  Med ens fingo de syn på Nils Holgersson, och då sköt den store v
# vila. När vildgässen och Nils Holgersson äntligen hade letat sig
#  slags arbetare. Men vad Nils Holgersson inte såg, det var, att s
# nde han fråga, och om då Nils Holgersson sade nej, började han ge
# de lille Mats, och om nu Nils Holgersson också hade tegat, så had
# åg så försmädlig ut, att Nils Holgersson kastade sig över honom f
#  brodern. Och inte ville Nils Holgersson slåss med en tös, utan h
# örkar. På den tiden, när Nils Holgersson for omkring med vildgäss
#  ryckte omkull honom. Om Nils Holgersson genast hade ropat på hjä
# u reda dig på egen hand, Nils Holgersson,» sade han då till sig s
# r satte Fumle-Drumle ner Nils Holgersson på bottnen av en sandgro
# mlingarna. – »Jo, jag är Nils Holgersson från Västra Vemmenhög, s
# rakten. På den tiden, då Nils Holgersson for omkring med vildgäss
# Jo, det står – Det står: Nils Holgersson fr. V. Vemmenhög.» »Det
# visan 1 Sveriges karta 2 Nils Holgerssons underbara resa genom Sv
# admalsvåden 233 ________ Nils Holgerssons underbara resa genom Sv
# R. Tolv år ungefär innan Nils Holgersson hade börjat resa omkring
# och leta efter föda, men Nils Holgersson hade på morgonen tappat
# ill i Närke det året, då Nils Holgersson for fram över landskapet
# hade flyttat tassen över Nils Holgerssons ansikte, så att den sta
# 29 april. Denna dag fick Nils Holgersson se södra Dalarna. Vildgä
# rliga sjön. Det året, då Nils Holgersson for med vildgässen genom
# t skänka upptäckten till Nils Holgersson. Det var ju både det tro
#  som sången varade, stod Nils Holgersson och lyssnade till den, m
# ova på en vassrugge. Vad Nils Holgersson angår, så var han för hu
# e svårt för en sådan som Nils Holgersson att finna en farkost. Ha
# r de hade kommit mittför Nils Holgersson, slogo de sig ner på ett
#  5 maj. På den tiden, då Nils Holgersson drog genom landet med vi
# an vara bra lycklig. Att Nils Holgersson, som för ett par timmar
#  afton. Och således hade Nils Holgersson fått se studenterna, när
# nger under marschen. Men Nils Holgersson hade tyckt, att det inte
# och glädja så som dessa. Nils Holgersson hade mest sett på studen
# m, stannade han. »Jag är Nils Holgersson från Västra Vemmenhög,»
#  Ett par år före det, då Nils Holgersson drog omkring med vildgäs
#  detsamma fattade han om Nils Holgersson med sin stora fot, höjde
# t ingen mer än den lilla Nils Holgersson, som följde henne. Solen
#  voro klädda med is, och Nils Holgersson ville följa henne dit in
# t Lappland är mitt!» Men Nils Holgersson hade blivit så ängslig,
#  över klippväggarna, och Nils Holgersson kunde förstå, att det va
#  SJUKDOMEN. Det året, då Nils Holgersson for omkring med vildgäss
# jligt att undgå den. Vad Nils Holgersson beträffar, så hade han h
# hade hon slagit klorna i Nils Holgerssons skuldra och hackade eft
# g, att just det året, då Nils Holgersson for omkring med vildgäss
#  lönt att vara bedrövad, Nils Holgersson,» sade solen. »Världen ä
# åga om han inte kunde ge Nils Holgersson bättre villkor. ’Det öns
# du vill,’ sade han. ’Med Nils Holgersson blir det ändå så, som ja
# a haft av honom. Ja, säg Nils Holgersson, att föräldrarna redan h
# Västergötland. Den lille Nils Holgersson hade krupit upp på en la
#  honom sämre.» Den lille Nils Holgersson hade följt med barnen he
# e bara störa.» Då tyckte Nils Holgersson, att när ingen annan gjo
# n färdig att följa det.» Nils Holgersson sprang raskt neråt vägen
# rott mellan de unga. Vad Nils Holgersson beträffar, så hade han i
# on gav sig tid att se på Nils Holgersson, innan hon stötte till.
#  ändå alldeles olik. Den Nils Holgersson, som hade farit bort i v
#  tro det. Välkommen hem, Nils Holgersson, välkommen hem! Det här
# mig här på gården,» sade Nils Holgersson. »Min egen mor tror, att
# on riktig sjukdom,» sade Nils Holgersson. »Jag får försöka ställa
# in kniv här på din hov?» Nils Holgersson var nätt och jämnt färdi
# sslingen, som var så lik Nils Holgersson, att om det inte var han
# pojken fanns i närheten. Nils Holgersson hörde honom nog, men han
# ottrar ihop ett tack för Nils Holgersson? Vad skulle det ha blivi

# %% [markdown]
# Run a simple <a href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">tokenization
# program</a> on your corpus.

# %%
def tokenize(text):
    words = re.findall('\p{L}+', text)
    return words

# %%
words = tokenize(corpus)
words[:10]
# Out:
# ['Selma',
#  'Lagerlöf',
#  'Nils',
#  'Holgerssons',
#  'underbara',
#  'resa',
#  'genom',
#  'Sverige',
#  'Första',
#  'bandet']

# %% [markdown]
# Count the number of unique words in the original corpus and when setting all the words in lowercase

# %% [markdown]
# Original text

# %%
# Write your code here
def text_to_idx(tokens):
    word_ind = dict()
    
    for i in tokens:
        
        word_ind[i] = 1

    return(len(word_ind.keys()))

print(text_to_idx(words))
# Out:
# 44256

# %% [markdown]
# Lowercased text

# %%
# Write your code here
words = tokenize(corpus.lower())
print(text_to_idx(words))
# Out:
# 41032

# %% [markdown]
# ### Segmenting a corpus

# %% [markdown]
# You will write a program to tokenize your text, insert `<s>` and `</s>` tags to delimit sentences, and set all the words in lowercase letters. In the end, you will only keep the words.

# %% [markdown]
# #### Normalizing

# %% [markdown]
# Write a regular expression that matches all the characters that are neither a letter nor a punctuation sign. The punctuations signs will be the followings: `.;:?!`. In your regex, use the same order. For the definition of a letter, use a Unicode regex. You will call the regex string `nonletter`

# %%
# Write your code
regex = '\p{L}+|[.;:?!]'
test_string = "En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa."
string_list = re.findall(regex, test_string)
text = ' '.join(string_list)
print(text)
# Out:
# En gång hade de på Mårbacka en barnpiga som hette Back Kajsa .

# %% [markdown]
# Write a `clean()` function that replaces all the characters that are neither a letter nor a punctuation sign with a space. The punctuations signs will be the followings: `.;:?!`.   For the sentence:
#
# _En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa._
#
# the result will be:
#
# `En gång hade de på Mårbacka en barnpiga som hette Back Kajsa.`

# %%
# Write your code here
def clean(text):
    regex = '[^(.:;?!)|\p{L}+]'
    return re.sub(regex, " ", text)

# %%
test_para = 'En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa.» – »\
Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, \
hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, \
när hon kammade dem, och till humöret var hon dyster och sorgbunden.'

# %%
test_para = clean(test_para)
test_para
# Out:
# 'En gång hade de på Mårbacka en barnpiga  som hette Back Kajsa.     Hon var nog sina tre alnar lång  hon hade ett stort  grovt ansikte med stränga  mörka drag  hennes händer voro hårda och fulla av sprickor  som barnens hår fastnade i  när hon kammade dem  och till humöret var hon dyster och sorgbunden.'

# %% [markdown]
# #### Segmenter

# %% [markdown]
# In this section, you will write a sentence segmenter that will delimit each sentence with `</s>` and `<s>` symbols. For example the sentence:
#
# _En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa._
#
# will be bracketed as:
#
# `<s> En gång hade de på Mårbacka en barnpiga som hette Back-Kajsa </s>`
#
# As algorithm, you will use a simple heuristics to detect the sentence boundaries: A sentence starts with a capital letter and ends with a period-equivalent punctuation sign. You will write a regex to match these boundaries with a regular expression and you will insert `</s>\n<s>` symbols with a substitution function.

# %% [markdown]
# ##### Detecting sentence boundaries

# %% [markdown]
# Write a regular expression that matches a punctuation, a sequence of spaces, and an uppercase letter. Call this regex string `sentence_boundaries`. In the regex, you will remember the value of the uppercase letter using a backreference. Use the Unicode regexes for the letters and the spaces.

# %%
# Write your code here
sentence_boundaries = "([.;:?!])\s+([A-Ö])"

# %% [markdown]
# ##### Replacement markup

# %% [markdown]
# Write a string to replace the matched boundaries with the sentence boundary markup. Remember that a sentence ends with `</s>` and starts with `<s>` and that there is one sentence per line. Hint: The markup is `</s>\n<s>`. Remember also that the first letter of your sentence is in a regex backreference. Call the regex string `sentence_markup`.

# %%
# Write your code here
sentance_markup = " </s>\n<s> \\2"

# %% [markdown]
# Use your regexes to segment your text. Use the string `sentence_boundaries`, `sentence_markup`, and `test_para` as input and `text` as output.

# %%
# Write your code here
test_para = 'En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa. \
Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, \
hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, \
när hon kammade dem, och till humöret var hon dyster och sorgbunden.'
text = re.sub(sentence_boundaries, sentance_markup, test_para, 0)

# %%
##### Applying the substitution

# %%
print(text)
# Out:
# En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden.

# %% [markdown]
# The output should look like this:
#
# `En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden.`

# %% [markdown]
# Insert markup codes in the beginning and end of the text

# %%
# Write your code here
def beg_end(text):
    text = re.sub("^", "<s> ", text, 1)
    text = re.sub("\s*$", " </s>", text, 1)
    return text
text1 = beg_end(text)
print(text1)
# Out:
# <s> En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden. </s>

# %% [markdown]
# The output should look like this:
#
# `<s> En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden. </s>`

# %% [markdown]
# Replace the space duplicates with one space and remove the punctuation signs. For the spaces, use the Unicode regex.

# %%
# Write your code here
def clean2(text):
    dup_space = "[\t\f ]+"
    punct = "[.;:?!]"
    text = re.sub(dup_space, " ", text, 0)
    text = re.sub(punct, "", text, 0)
    return text
text2 = clean2(text1)
print(text2)
# Out:
# <s> En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden </s>

# %% [markdown]
# The output should look like this:
#
# `<s> En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa </s>
# <s> Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, när hon kammade dem, och till humöret var hon dyster och sorgbunden </s>`

# %% [markdown]
# Write a `segment_sentences(text)` function to gather the code in the Segmenter section and set the text in lowercase

# %%
# Write your code here
def segment_sentences(text):
    text = clean(text)
    text = re.sub(sentence_boundaries, sentance_markup, text, 0)
    text = beg_end(text)
    text = clean2(text).lower()
    return text

# %%
print(segment_sentences(test_para))
# Out:
# <s> en gång hade de på mårbacka en barnpiga som hette back kajsa </s>
# <s> hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden </s>

# %% [markdown]
# Estimate roughly the accuracy of your program.

# %% [markdown]
# #### Tokenizing the corpus

# %% [markdown]
# Clean and segment the corpus

# %%
# Write your code here
corpus2 = segment_sentences(clean_corpus)

# %%
print(corpus2[-557:])
# Out:
# <s> hon hade fått större kärlek av sina föräldrar än någon annan han visste och sådan kärlek måste vändas i välsignelse </s>
# <s> då prästen sade detta kom alla människor att se bort mot klara gulla och de förundrade sig över vad de såg </s>
# <s> prästens ord tycktes redan ha gått i uppfyllelse </s>
# <s> där stod klara fina gulleborg ifrån skrolycka hon som var uppkallad efter själva solen vid sina föräldrars grav och lyste som en förklarad </s>
# <s> hon var likaså vacker som den söndagen då hon gick till kyrkan i den röda klänningen om inte vackrare </s>

# %% [markdown]
# The result should be a normalized text without punctuation signs where all the sentences are delimited with `<s>` and `</s>` tags. The five last lines of the text should look like this:
#
# ```
# <s> hon hade fått större kärlek av sina föräldrar än någon annan han visste och sådan kärlek måste vändas i välsignelse </s>
# <s> då prästen sade detta kom alla människor att se bort mot klara gulla och de förundrade sig över vad de såg </s>
# <s> prästens ord tycktes redan ha gått i uppfyllelse </s>
# <s> där stod klara fina gulleborg ifrån skrolycka hon som var uppkallad efter själva solen vid sina föräldrars grav och lyste som en förklarad </s>
# <s> hon var likaså vacker som den söndagen då hon gick till kyrkan i den röda klänningen om inte vackrare </s>
# ```

# %% [markdown]
# You will now create a list of words from your string. You will consider that a space or a carriage return is an item separator

# %%
# Write your code here
listify = "<s>|</s>|\p{L}+"
words = re.findall(listify, corpus2)
#import json

#with open('wordtest.txt', 'w') as f:
    #f.write(json.dumps(' '.join(words)))

# %%
print(words[-101:])
# Out:
# ['<s>', 'hon', 'hade', 'fått', 'större', 'kärlek', 'av', 'sina', 'föräldrar', 'än', 'någon', 'annan', 'han', 'visste', 'och', 'sådan', 'kärlek', 'måste', 'vändas', 'i', 'välsignelse', '</s>', '<s>', 'då', 'prästen', 'sade', 'detta', 'kom', 'alla', 'människor', 'att', 'se', 'bort', 'mot', 'klara', 'gulla', 'och', 'de', 'förundrade', 'sig', 'över', 'vad', 'de', 'såg', '</s>', '<s>', 'prästens', 'ord', 'tycktes', 'redan', 'ha', 'gått', 'i', 'uppfyllelse', '</s>', '<s>', 'där', 'stod', 'klara', 'fina', 'gulleborg', 'ifrån', 'skrolycka', 'hon', 'som', 'var', 'uppkallad', 'efter', 'själva', 'solen', 'vid', 'sina', 'föräldrars', 'grav', 'och', 'lyste', 'som', 'en', 'förklarad', '</s>', '<s>', 'hon', 'var', 'likaså', 'vacker', 'som', 'den', 'söndagen', 'då', 'hon', 'gick', 'till', 'kyrkan', 'i', 'den', 'röda', 'klänningen', 'om', 'inte', 'vackrare', '</s>']

# %% [markdown]
# The five last lines of the corpus should like this:
#
# `['<s>', 'hon', 'hade', 'fått', 'större', 'kärlek', 'av', 'sina', 'föräldrar', 'än', 'någon', 'annan', 'han', 'visste', 'och', 'sådan', 'kärlek', 'måste', 'vändas', 'i', 'välsignelse', '</s>', '<s>', 'då', 'prästen', 'sade', 'detta', 'kom', 'alla', 'människor', 'att', 'se', 'bort', 'mot', 'klara', 'gulla', 'och', 'de', 'förundrade', 'sig', 'över', 'vad', 'de', 'såg', '</s>', '<s>', 'prästens', 'ord', 'tycktes', 'redan', 'ha', 'gått', 'i', 'uppfyllelse', '</s>', '<s>', 'där', 'stod', 'klara', 'fina', 'gulleborg', 'ifrån', 'skrolycka', 'hon', 'som', 'var', 'uppkallad', 'efter', 'själva', 'solen', 'vid', 'sina', 'föräldrars', 'grav', 'och', 'lyste', 'som', 'en', 'förklarad', '</s>', '<s>', 'hon', 'var', 'likaså', 'vacker', 'som', 'den', 'söndagen', 'då', 'hon', 'gick', 'till', 'kyrkan', 'i', 'den', 'röda', 'klänningen', 'om', 'inte', 'vackrare', '</s>']`

# %% [markdown]
# ### Counting unigrams and bigrams

# %% [markdown]
# Read and try programs to compute the frequency of unigrams and bigrams of the training set: [<a
#             href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">Program folder</a>].

# %% [markdown]
# #### Unigrams

# %%
def unigrams(words):
    frequency = {}
    for i in range(len(words)):
        if words[i] in frequency:
            frequency[words[i]] += 1
        else:
            frequency[words[i]] = 1
    return frequency

# %% [markdown]
# We compute the frequencies.

# %%
frequency = unigrams(words)
list(frequency.items())[:20]
# Out:
# [('<s>', 60967),
#  ('selma', 52),
#  ('lagerlöf', 270),
#  ('nils', 87),
#  ('holgerssons', 6),
#  ('underbara', 23),
#  ('resa', 317),
#  ('genom', 688),
#  ('sverige', 56),
#  ('</s>', 60967),
#  ('första', 525),
#  ('bandet', 6),
#  ('bokutgåva', 11),
#  ('albert', 15),
#  ('bonniers', 11),
#  ('förlag', 11),
#  ('stockholm', 77),
#  ('den', 11624),
#  ('kristliga', 2),
#  ('dagvisan', 2)]

# %% [markdown]
# #### Bigrams

# %%
def bigrams(words):
    bigrams = []
    for i in range(len(words) - 1):
        bigrams.append((words[i], words[i + 1]))
    frequency_bigrams = {}
    for i in range(len(words) - 1):
        if bigrams[i] in frequency_bigrams:
            frequency_bigrams[bigrams[i]] += 1
        else:
            frequency_bigrams[bigrams[i]] = 1
    return frequency_bigrams

# %%
frequency_bigrams = bigrams(words)
list(frequency_bigrams.items())[:20]
# Out:
# [(('<s>', 'selma'), 8),
#  (('selma', 'lagerlöf'), 11),
#  (('lagerlöf', 'nils'), 1),
#  (('nils', 'holgerssons'), 6),
#  (('holgerssons', 'underbara'), 4),
#  (('underbara', 'resa'), 4),
#  (('resa', 'genom'), 6),
#  (('genom', 'sverige'), 5),
#  (('sverige', '</s>'), 19),
#  (('</s>', '<s>'), 60974),
#  (('<s>', 'första'), 11),
#  (('första', 'bandet'), 1),
#  (('bandet', 'bokutgåva'), 2),
#  (('bokutgåva', 'albert'), 11),
#  (('albert', 'bonniers'), 11),
#  (('bonniers', 'förlag'), 11),
#  (('förlag', 'stockholm'), 10),
#  (('stockholm', '</s>'), 24),
#  (('<s>', 'den'), 1382),
#  (('den', 'kristliga'), 2)]

# %% [markdown]
# In the report, tell what is the possible number of bigrams and their real number? Explain why such a difference. What would be the possible number of 4-grams.
#
# Propose a solution to cope with bigrams unseen in the corpus. This topic will be discussed during the lab session.

# %% [markdown]
# ### Computing the likelihood of a sentence

# %% [markdown]
# #### Unigrams

# %% [markdown]
# Write a program to compute a sentence's probability using unigrams. You may find useful the dictionaries that we saw in the mutual information program: [<a href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">Program folder</a>]. Your function will return the perplexity.

# %% [markdown]
# Your function should print and tabulate the results as in the examples below with the sentence _Det var en gång en katt som hette Nils_.

# %% [markdown]
# ```
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# det 	 21108 	 1041631 	 0.0202643738521607
# var 	 12090 	 1041631 	 0.01160679741674355
# en 	 13514 	 1041631 	 0.01297388422579589
# gång 	 1332 	 1041631 	 0.001278763784871994
# en 	 13514 	 1041631 	 0.01297388422579589
# katt 	 16 	 1041631 	 1.5360525944408337e-05
# som 	 16288 	 1041631 	 0.015637015411407686
# hette 	 97 	 1041631 	 9.312318853797554e-05
# nils 	 87 	 1041631 	 8.352285982272032e-05
# </s> 	 59047 	 1041631 	 0.056687060964967444
# =====================================================
# Prob. unigrams:	 5.361459667285409e-27
# Geometric mean prob.: 0.0023600885848765307
# Entropy rate:	 8.726943273141258
# Perplexity:	 423.71290908655254
# ```

# %%
# Write your code
def unigram_lm(frequency, sent_words):
    num_words = len(words)
    num_sent = len(sent_words)
    entropy = 0.0
    prob_uni = 1.0
    print("=====================================================")
    print("wi       C(wi)   #words          P(wi)")
    print("=====================================================")
    for word in sent_words:
        c_w = frequency[word]
        P_w = c_w/num_words
        prob_uni = prob_uni * P_w
        entropy = entropy + math.log(P_w,2)
        
        print("%s \t %d \t %d \t %f" %(word, c_w, num_words, P_w))
    entropy = -1*entropy/float(num_sent)
    perp = 2**entropy
    print("=====================================================")
    print("Prob. unigram: \t %e" %prob_uni)
    print("Geometric mean:  %f" %prob_uni**(1/float(num_sent)))
    print("Entropy rate: \t %f" %entropy)
    print("Perplexity: \t %f" %perp)
    return(perp)

# %%
sentence = 'det var en gång en katt som hette nils </s>'
sent_words = sentence.split()
sent_words
# Out:
# ['det', 'var', 'en', 'gång', 'en', 'katt', 'som', 'hette', 'nils', '</s>']

# %%
perplexity_unigrams = unigram_lm(frequency, sent_words)
# Out:
# =====================================================
# wi       C(wi)   #words          P(wi)
# =====================================================
# det 	 21108 	 1045416 	 0.020191
# var 	 12090 	 1045416 	 0.011565
# en 	 13514 	 1045416 	 0.012927
# gång 	 1332 	 1045416 	 0.001274
# en 	 13514 	 1045416 	 0.012927
# katt 	 16 	 1045416 	 0.000015
# som 	 16288 	 1045416 	 0.015580
# hette 	 97 	 1045416 	 0.000093
# nils 	 87 	 1045416 	 0.000083
# </s> 	 60975 	 1045416 	 0.058326
# =====================================================
# Prob. unigram: 	 5.339303e-27
# Geometric mean:  0.002359
# Entropy rate: 	 8.727541
# Perplexity: 	 423.888412

# %%
perplexity_unigrams = int(perplexity_unigrams)
perplexity_unigrams
# Out:
# 423

# %% [markdown]
# #### Bigrams

# %% [markdown]
# Write a program to compute the sentence probability using bigrams. Your function will tabulate and print the results as below. It will return the perplexity.

# %% [markdown]
# ```
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	 det 	 5672 	 59047 	 0.09605907158704083
# det 	 var 	 3839 	 21108 	 0.1818741709304529
# var 	 en 	 712 	 12090 	 0.058891645988420185
# en 	 gång 	 706 	 13514 	 0.052242119283705785
# gång 	 en 	 20 	 1332 	 0.015015015015015015
# en 	 katt 	 6 	 13514 	 0.0004439840165754033
# katt 	 som 	 2 	 16 	 0.125
# som 	 hette 	 45 	 16288 	 0.002762770137524558
# hette 	 nils 	 0 	 97 	 0.0 	 *backoff: 	 8.352285982272032e-05
# nils 	 </s> 	 2 	 87 	 0.022988505747126436
# =====================================================
# Prob. bigrams:	 2.376007803503683e-19
# Geometric mean prob.: 0.013727289294133601
# Entropy rate:	 6.186809422848149
# Perplexity:	 72.84759420254609
# ```

# %%
# Write your code
def bigram_lm(frequency, frequency_bigrams, sent_words):
    num_words = len(words)
    num_sent = len(sent_words)
    entropy = 0.0
    prob_bi = frequency[sent_words[0]]/float(num_words)
    print("=====================================================")
    print("wi      wi+1      Ci,i+1      C(i)      P(wi+1|wi)")
    print("=====================================================")
    for i in range(num_sent):
        w1 = sent_words[i]
        if i + 1 < num_sent:
            w2 = sent_words[i + 1]
            seq = (w1, w2)
            
            if seq in frequency_bigrams:
                ci_i1 = frequency_bigrams[seq]
            else:
                ci_i1 = 0
            ci = frequency[w1]
            if ci_i1 != 0:
                p = ci_i1/frequency[w1]
                prob_bi = prob_bi * p
                entropy = entropy + math.log(p,2)
                p = str(p)
            else:
                p = frequency[w2]/num_words
                prob_bi = prob_bi * p
                entropy = entropy + math.log(p,2)
                p = "0.0 \t *backoff: \t " + str(p)
            print("%s \t  %s \t %d \t %d \t %s " %(w1, w2, ci_i1, ci, p))
    entropy = -1*entropy/float(num_sent)
    perp = 2**entropy
    print("=====================================================")
    print("Prob. bigram: \t %e" %prob_bi)
    print("Geometric mean:  %f" %prob_bi**(1/float(num_sent)))
    print("Entropy rate: \t %f" %entropy)
    print("Perplexity: \t %f" %perp)
    #return(perp)

# %%
sentence = '<s> det var en gång en katt som hette nils </s>'
sent_words = sentence.split()
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words)
# Out:
# =====================================================
# wi      wi+1      Ci,i+1      C(i)      P(wi+1|wi)
# =====================================================
# <s> 	  det 	 5690 	 60975 	 0.09331693316933169
# det 	  var 	 3838 	 21108 	 0.181826795527762
# var 	  en 	 712 	 12090 	 0.058891645988420185
# en 	  gång 	 706 	 13514 	 0.052242119283705785
# gång 	  en 	 20 	 1332 	 0.015015015015015015
# en 	  katt 	 6 	 13514 	 0.0004439840165754033
# katt 	  som 	 2 	 16 	 0.125
# som 	  hette 	 45 	 16288 	 0.002762770137524558
# hette 	  nils 	 0 	 97 	 0.0 	 *backoff: 	 8.32204596065107e-05
# nils 	  </s> 	 2 	 87 	 0.022988505747126436
# =====================================================
# Prob. bigram: 	 1.341048e-20
# Geometric mean:  0.015610
# Entropy rate: 	 5.628681
# Perplexity: 	 49.476808

# %%
perplexity_bigrams = int(perplexity_bigrams)
perplexity_bigrams
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-eb904a61af83> in <module>
# ----> 1 perplexity_bigrams = int(perplexity_bigrams)
#       2 perplexity_bigrams
#
# NameError: name 'perplexity_bigrams' is not defined

# %% [markdown]
# In addition to this sentence, _Det var en gång en katt som hette Nils_, write five other sentences that will form your test set and run your programs on them. You will insert them in your report.

# %% [markdown]
# ### Online prediction of words

# %% [markdown]
# You will now carry out an online prediction of words. You will consider two cases:
# 1. Prediction of the current word a user is typing;
# 2. Prediction of the next word.
#
# Ideally, you would write a loop that reads the words and apply the models while typing. As the Jupyter labs are not designed for interactive input and output, we will simplify the experimental settings with constant strings at a given time of the input.
#
# We will assume the user is typing the phrase: _Det var en gång_.

# %% [markdown]
# #### Trigrams

# %% [markdown]
# To have a more accurate prediction, you will use a trigram counting function. Program it following the model of bigrams.

# %%
# Write your code
def trigrams(words):
    trigrams = []
    for i in range(len(words) - 2):
        trigrams.append((words[i], words[i + 1], words[i + 2]))
    frequency_trigrams = {}
    for i in range(len(words) - 2):
        if trigrams[i] in frequency_trigrams:
            frequency_trigrams[trigrams[i]] += 1
        else:
            frequency_trigrams[trigrams[i]] = 1
    return frequency_trigrams

# %%
frequency_trigrams = trigrams(words)
frequency_trigrams[('det', 'var', 'en')]
# Out:
# 329

# %% [markdown]
# #### Prediction

# %% [markdown]
# The user starts typing _Det var en gång_. After the 2nd character, your program tries to help the user with suggested words.

# %%
starting_text = 'De'.lower()

# %% [markdown]
# Write a program to rank the five first candidates at this point. Assign these predictions in a list that you will call `current_word_predictions_1`. Note that you are starting a sentence and you can then use the bigram frequencies.

# %%
cand_nbr = 5

# %%
# Write your code here
def pred(starting_text, cand_nbr):
    ret = {}
    reg = " de\p{L}*"
    word_string = ' '.join(list(frequency.keys()))
    text_list = re.findall(reg, word_string)
    for i in text_list:
        i = re.sub(" ", "", i)
        key = ("<s>", i)
        if key in frequency_bigrams:
            ret[i] = frequency_bigrams[key]
    
    ret = {k: v for k, v in sorted(ret.items(), key=lambda item: item[1])}
    ret = list(ret.keys())
    ret = ret[::-1]
    return(ret[:cand_nbr])

current_word_predictions_1 = pred(starting_text, cand_nbr)

# %%
current_word_predictions_1
# Out:
# ['det', 'de', 'den', 'detta', 'denna']

# %% [markdown]
# Let us now suppose that the user has typed: _Det var en_. After detecting a space, your program starts predicting a next possible word.

# %%
current_text = "Det var en ".lower()

# %% [markdown]
# Tokenize this text and return a list of tokens. Call it `tokens`.

# %%
# Write your code here
tokens = tokenize(current_text)

# %%
tokens
# Out:
# ['det', 'var', 'en']

# %% [markdown]
# Write a program to propose the five next possible words ranked by frequency using a trigram model. Assign these predictions to a variable that you will call `next_word_predictions`

# %%
# Write your code here
def pred_next(tokens, cand_nbr):
    ret = {}
    
    trigram_list = list(frequency.keys())
    for i in trigram_list:
        key = (tokens[1], tokens[2], i)
        if key in frequency_trigrams:
            ret[i] = frequency_trigrams[key]
    
    ret = {k: v for k, v in sorted(ret.items(), key=lambda item: item[1])}
    ret = list(ret.keys())
    ret = ret[::-1]
    return(ret[:cand_nbr])
next_word_predictions = pred_next(tokens, cand_nbr)

# %%
next_word_predictions
# Out:
# ['stor', 'liten', 'gammal', 'god', 'sådan']

# %% [markdown]
# Finally, let us suppose that the user has typed _Det var en g_, rank the five possible candidates. Assign these predictions in a list that you will call `current_word_predictions_2`

# %%
current_text = "Det var en g".lower()

# %%
# Write your code here
def pred_next2(words, cand_nbr):
    word_list = tokenize(words)
    reg = " " + word_list[-1] +"\p{L}*"
    word_string = ' '.join(list(frequency.keys()))
    text_list = re.findall(reg, word_string)
    ret = {}
    for i in text_list:
        i = re.sub(" ", "", i)
        key = (word_list[-3], word_list[-2], i)
        if key in frequency_trigrams:
            ret[i] = frequency_trigrams[key]
    
    ret = {k: v for k, v in sorted(ret.items(), key=lambda item: item[1])}
    ret = list(ret.keys())
    ret = ret[::-1]
    return(ret[:cand_nbr])
current_word_predictions_2 = pred_next2(current_text, cand_nbr)
# Out:
# ('var', 'en', 'genom')
# ('var', 'en', 'glädje')
# ('var', 'en', 'gud')
# ('var', 'en', 'glad')
# ('var', 'en', 'gå')
# ('var', 'en', 'gamla')
# ('var', 'en', 'gränser')
# ('var', 'en', 'gult')
# ('var', 'en', 'grönt')
# ('var', 'en', 'glänser')
# ('var', 'en', 'gledo')
# ('var', 'en', 'gälla')
# ('var', 'en', 'gossens')
# ('var', 'en', 'giv')
# ('var', 'en', 'gång')
# ('var', 'en', 'gärning')
# ('var', 'en', 'gammal')
# ('var', 'en', 'göra')
# ('var', 'en', 'gingo')
# ('var', 'en', 'gissat')
# ('var', 'en', 'gör')
# ('var', 'en', 'gjorde')
# ('var', 'en', 'gången')
# ('var', 'en', 'gick')
# ('var', 'en', 'går')
# ('var', 'en', 'genast')
# ('var', 'en', 'ganska')
# ('var', 'en', 'gris')
# ('var', 'en', 'gäss')
# ('var', 'en', 'gått')
# ('var', 'en', 'glada')
# ('var', 'en', 'ge')
# ('var', 'en', 'glänt')
# ('var', 'en', 'gässen')
# ('var', 'en', 'gården')
# ('var', 'en', 'gåvo')
# ('var', 'en', 'gammaldags')
# ('var', 'en', 'gånger')
# ('var', 'en', 'grensle')
# ('var', 'en', 'gammalt')
# ('var', 'en', 'grytorna')
# ('var', 'en', 'gafflar')
# ('var', 'en', 'gjort')
# ('var', 'en', 'gott')
# ('var', 'en', 'guldpenning')
# ('var', 'en', 'gett')
# ('var', 'en', 'gav')
# ('var', 'en', 'golvet')
# ('var', 'en', 'galet')
# ('var', 'en', 'gömd')
# ('var', 'en', 'grät')
# ('var', 'en', 'gosse')
# ('var', 'en', 'gråsparv')
# ('var', 'en', 'gåsapåg')
# ('var', 'en', 'gol')
# ('var', 'en', 'gående')
# ('var', 'en', 'genombeskedlig')
# ('var', 'en', 'gröna')
# ('var', 'en', 'glömde')
# ('var', 'en', 'gapet')
# ('var', 'en', 'glömma')
# ('var', 'en', 'gull')
# ('var', 'en', 'getingen')
# ('var', 'en', 'gråtit')
# ('var', 'en', 'gifta')
# ('var', 'en', 'gåsamor')
# ('var', 'en', 'galna')
# ('var', 'en', 'gåskarl')
# ('var', 'en', 'gåskarlen')
# ('var', 'en', 'gärdsgården')
# ('var', 'en', 'gåsflocken')
# ('var', 'en', 'gåskarlens')
# ('var', 'en', 'gåsryggen')
# ('var', 'en', 'glatta')
# ('var', 'en', 'gripa')
# ('var', 'en', 'gulgråa')
# ('var', 'en', 'gula')
# ('var', 'en', 'gulnade')
# ('var', 'en', 'grått')
# ('var', 'en', 'gårdarna')
# ('var', 'en', 'gårdsplanerna')
# ('var', 'en', 'gräsmattorna')
# ('var', 'en', 'grönska')
# ('var', 'en', 'grynlösa')
# ('var', 'en', 'granna')
# ('var', 'en', 'gård')
# ('var', 'en', 'gåsapiga')
# ('var', 'en', 'god')
# ('var', 'en', 'gåslängder')
# ('var', 'en', 'gåsen')
# ('var', 'en', 'gärna')
# ('var', 'en', 'grenarna')
# ('var', 'en', 'gåsryttaren')
# ('var', 'en', 'grep')
# ('var', 'en', 'gåvan')
# ('var', 'en', 'gåsfolk')
# ('var', 'en', 'glömt')
# ('var', 'en', 'gråa')
# ('var', 'en', 'gåsvaktare')
# ('var', 'en', 'grövre')
# ('var', 'en', 'gässlingarna')
# ('var', 'en', 'gällde')
# ('var', 'en', 'ger')
# ('var', 'en', 'gräs')
# ('var', 'en', 'gräset')
# ('var', 'en', 'gås')
# ('var', 'en', 'goda')
# ('var', 'en', 'gåsens')
# ('var', 'en', 'grentaket')
# ('var', 'en', 'gren')
# ('var', 'en', 'grenvalvet')
# ('var', 'en', 'grenen')
# ('var', 'en', 'gul')
# ('var', 'en', 'grenar')
# ('var', 'en', 'gråta')
# ('var', 'en', 'guldgul')
# ('var', 'en', 'gåsleken')
# ('var', 'en', 'gripit')
# ('var', 'en', 'grå')
# ('var', 'en', 'glimmade')
# ('var', 'en', 'gömde')
# ('var', 'en', 'gångarna')
# ('var', 'en', 'grann')
# ('var', 'en', 'glans')
# ('var', 'en', 'gap')
# ('var', 'en', 'gäckas')
# ('var', 'en', 'grönmålat')
# ('var', 'en', 'gille')
# ('var', 'en', 'gumman')
# ('var', 'en', 'granngårdspojkarna')
# ('var', 'en', 'gårdsporten')
# ('var', 'en', 'gårdsplanen')
# ('var', 'en', 'gnistra')
# ('var', 'en', 'grön')
# ('var', 'en', 'gavlar')
# ('var', 'en', 'grav')
# ('var', 'en', 'glimminge')
# ('var', 'en', 'gardiner')
# ('var', 'en', 'gyllenläderstapeter')
# ('var', 'en', 'gift')
# ('var', 'en', 'genskjuta')
# ('var', 'en', 'goa')
# ('var', 'en', 'gräsmattor')
# ('var', 'en', 'granhult')
# ('var', 'en', 'godset')
# ('var', 'en', 'gräsrötter')
# ('var', 'en', 'gränsade')
# ('var', 'en', 'gengäld')
# ('var', 'en', 'gömställen')
# ('var', 'en', 'gåsvinge')
# ('var', 'en', 'grymma')
# ('var', 'en', 'granngårdarna')
# ('var', 'en', 'glimmingehus')
# ('var', 'en', 'gråråttor')
# ('var', 'en', 'gråråttorna')
# ('var', 'en', 'godo')
# ('var', 'en', 'gitte')
# ('var', 'en', 'gemensamt')
# ('var', 'en', 'gråråttornas')
# ('var', 'en', 'grannsämja')
# ('var', 'en', 'gårdsfolket')
# ('var', 'en', 'gurgla')
# ('var', 'en', 'groda')
# ('var', 'en', 'grästuvor')
# ('var', 'en', 'gråstrimmig')
# ('var', 'en', 'grymhet')
# ('var', 'en', 'grälade')
# ('var', 'en', 'gråråtta')
# ('var', 'en', 'gluggen')
# ('var', 'en', 'gråråttan')
# ('var', 'en', 'gångar')
# ('var', 'en', 'genomforska')
# ('var', 'en', 'genomforskat')
# ('var', 'en', 'glatt')
# ('var', 'en', 'gäll')
# ('var', 'en', 'gjord')
# ('var', 'en', 'gryningen')
# ('var', 'en', 'grottor')
# ('var', 'en', 'givet')
# ('var', 'en', 'gröngula')
# ('var', 'en', 'gråsparvar')
# ('var', 'en', 'gråblått')
# ('var', 'en', 'gräsligaste')
# ('var', 'en', 'göinge')
# ('var', 'en', 'givit')
# ('var', 'en', 'grämer')
# ('var', 'en', 'gjordes')
# ('var', 'en', 'gensägelse')
# ('var', 'en', 'gömslen')
# ('var', 'en', 'grad')
# ('var', 'en', 'gripits')
# ('var', 'en', 'glidande')
# ('var', 'en', 'genomvåt')
# ('var', 'en', 'glädjeskrik')
# ('var', 'en', 'genljöd')
# ('var', 'en', 'gled')
# ('var', 'en', 'glasverandor')
# ('var', 'en', 'geografi')
# ('var', 'en', 'granar')
# ('var', 'en', 'gråsten')
# ('var', 'en', 'grus')
# ('var', 'en', 'glasbjörk')
# ('var', 'en', 'gran')
# ('var', 'en', 'gräver')
# ('var', 'en', 'grävt')
# ('var', 'en', 'gammaljätten')
# ('var', 'en', 'gåsvingen')
# ('var', 'en', 'grinade')
# ('var', 'en', 'grymmaste')
# ('var', 'en', 'gässens')
# ('var', 'en', 'gnida')
# ('var', 'en', 'gräla')
# ('var', 'en', 'gömmer')
# ('var', 'en', 'genomskinlig')
# ('var', 'en', 'glas')
# ('var', 'en', 'glittrande')
# ('var', 'en', 'glädja')
# ('var', 'en', 'gripe')
# ('var', 'en', 'gripes')
# ('var', 'en', 'gällt')
# ('var', 'en', 'gatan')
# ('var', 'en', 'guld')
# ('var', 'en', 'guldpelare')
# ('var', 'en', 'guldet')
# ('var', 'en', 'guldfläckarna')
# ('var', 'en', 'glida')
# ('var', 'en', 'galejor')
# ('var', 'en', 'gatorna')
# ('var', 'en', 'grov')
# ('var', 'en', 'grova')
# ('var', 'en', 'gata')
# ('var', 'en', 'godmodig')
# ('var', 'en', 'grundlagt')
# ('var', 'en', 'gator')
# ('var', 'en', 'gillade')
# ('var', 'en', 'galjonsbilderna')
# ('var', 'en', 'grundade')
# ('var', 'en', 'gjorda')
# ('var', 'en', 'grågäss')
# ('var', 'en', 'grågås')
# ('var', 'en', 'grågåsen')
# ('var', 'en', 'grisslor')
# ('var', 'en', 'gräsänderna')
# ('var', 'en', 'gåslängd')
# ('var', 'en', 'galningar')
# ('var', 'en', 'gränslös')
# ('var', 'en', 'gunga')
# ('var', 'en', 'grundet')
# ('var', 'en', 'grannaste')
# ('var', 'en', 'gräva')
# ('var', 'en', 'gräsandhona')
# ('var', 'en', 'glädjen')
# ('var', 'en', 'godnatt')
# ('var', 'en', 'gåskarls')
# ('var', 'en', 'grågåsens')
# ('var', 'en', 'genompyrd')
# ('var', 'en', 'gamle')
# ('var', 'en', 'gungningen')
# ('var', 'en', 'gungat')
# ('var', 'en', 'grotta')
# ('var', 'en', 'grottan')
# ('var', 'en', 'gladde')
# ('var', 'en', 'glänsande')
# ('var', 'en', 'grottväggen')
# ('var', 'en', 'gumse')
# ('var', 'en', 'gäster')
# ('var', 'en', 'grop')
# ('var', 'en', 'gumsen')
# ('var', 'en', 'gottland')
# ('var', 'en', 'grottorna')
# ('var', 'en', 'grottöppningen')
# ('var', 'en', 'grand')
# ('var', 'en', 'grottans')
# ('var', 'en', 'gumsens')
# ('var', 'en', 'gårdagsstormen')
# ('var', 'en', 'grässtrå')
# ('var', 'en', 'grunden')
# ('var', 'en', 'gavel')
# ('var', 'en', 'gavlarna')
# ('var', 'en', 'glasbitar')
# ('var', 'en', 'gummor')
# ('var', 'en', 'garvades')
# ('var', 'en', 'guldsmeder')
# ('var', 'en', 'gulddragaren')
# ('var', 'en', 'guldtråd')
# ('var', 'en', 'gärdsgård')
# ('var', 'en', 'gyllene')
# ('var', 'en', 'guldsmidda')
# ('var', 'en', 'guldskrudar')
# ('var', 'en', 'gavelhusen')
# ('var', 'en', 'guldtyg')
# ('var', 'en', 'guldmynt')
# ('var', 'en', 'gårdar')
# ('var', 'en', 'gitarrer')
# ('var', 'en', 'godtemplare')
# ('var', 'en', 'guldinskrifterna')
# ('var', 'en', 'gavelhus')
# ('var', 'en', 'gavelhusens')
# ('var', 'en', 'golven')
# ('var', 'en', 'gräsbeväxta')
# ('var', 'en', 'gyllne')
# ('var', 'en', 'gräma')
# ('var', 'en', 'grant')
# ('var', 'en', 'gåsfjärden')
# ('var', 'en', 'glömmer')
# ('var', 'en', 'grenna')
# ('var', 'en', 'godlynt')
# ('var', 'en', 'gömt')
# ('var', 'en', 'götaland')
# ('var', 'en', 'garm')
# ('var', 'en', 'grym')
# ('var', 'en', 'gropen')
# ('var', 'en', 'grustag')
# ('var', 'en', 'gned')
# ('var', 'en', 'granskog')
# ('var', 'en', 'grantopp')
# ('var', 'en', 'gissa')
# ('var', 'en', 'gömda')
# ('var', 'en', 'gömma')
# ('var', 'en', 'gömställe')
# ('var', 'en', 'gavelväggen')
# ('var', 'en', 'grötgrytan')
# ('var', 'en', 'grisslan')
# ('var', 'en', 'garnhärvor')
# ('var', 'en', 'gardinen')
# ('var', 'en', 'greps')
# ('var', 'en', 'goddag')
# ('var', 'en', 'gåsflock')
# ('var', 'en', 'grannar')
# ('var', 'en', 'gapande')
# ('var', 'en', 'gångjärn')
# ('var', 'en', 'gnisslande')
# ('var', 'en', 'gumma')
# ('var', 'en', 'gottgöra')
# ('var', 'en', 'gorma')
# ('var', 'en', 'gräsand')
# ('var', 'en', 'gråhårig')
# ('var', 'en', 'göras')
# ('var', 'en', 'gungstol')
# ('var', 'en', 'grannarna')
# ('var', 'en', 'granskogar')
# ('var', 'en', 'gruvarbetarna')
# ('var', 'en', 'gåskacklet')
# ('var', 'en', 'gåskackel')
# ('var', 'en', 'gräsanden')
# ('var', 'en', 'grund')
# ('var', 'en', 'ginge')
# ('var', 'en', 'gräsliga')
# ('var', 'en', 'gryn')
# ('var', 'en', 'gossen')
# ('var', 'en', 'gräsänder')
# ('var', 'en', 'golv')
# ('var', 'en', 'gräsändernas')
# ('var', 'en', 'gorgo')
# ('var', 'en', 'grodungar')
# ('var', 'en', 'gäspade')
# ('var', 'en', 'gillar')
# ('var', 'en', 'gläder')
# ('var', 'en', 'grässtråna')
# ('var', 'en', 'grimma')
# ('var', 'en', 'gäller')
# ('var', 'en', 'grimman')
# ('var', 'en', 'godhet')
# ('var', 'en', 'grind')
# ('var', 'en', 'gillat')
# ('var', 'en', 'gisten')
# ('var', 'en', 'granngården')
# ('var', 'en', 'gistna')
# ('var', 'en', 'grubblade')
# ('var', 'en', 'guds')
# ('var', 'en', 'genomstungen')
# ('var', 'en', 'gästa')
# ('var', 'en', 'gnäggade')
# ('var', 'en', 'grisar')
# ('var', 'en', 'guldvävd')
# ('var', 'en', 'gyllentyget')
# ('var', 'en', 'guldslöjor')
# ('var', 'en', 'givmild')
# ('var', 'en', 'göta')
# ('var', 'en', 'glidit')
# ('var', 'en', 'goanisse')
# ('var', 'en', 'gråfälls')
# ('var', 'en', 'gränsen')
# ('var', 'en', 'grundmurar')
# ('var', 'en', 'gränsberget')
# ('var', 'en', 'grusbackar')
# ('var', 'en', 'genomvävd')
# ('var', 'en', 'gränsfolket')
# ('var', 'en', 'gruvarbetare')
# ('var', 'en', 'gruvor')
# ('var', 'en', 'genomhuggna')
# ('var', 'en', 'gruvbrytningen')
# ('var', 'en', 'gruvan')
# ('var', 'en', 'gallra')
# ('var', 'en', 'gnällde')
# ('var', 'en', 'gnälla')
# ('var', 'en', 'grönsaksland')
# ('var', 'en', 'gråfäll')
# ('var', 'en', 'grannare')
# ('var', 'en', 'gängliga')
# ('var', 'en', 'glimtade')
# ('var', 'en', 'görningen')
# ('var', 'en', 'gungflyn')
# ('var', 'en', 'gungade')
# ('var', 'en', 'gransnår')
# ('var', 'en', 'gråvita')
# ('var', 'en', 'granbarr')
# ('var', 'en', 'gyttja')
# ('var', 'en', 'giftiga')
# ('var', 'en', 'grodorna')
# ('var', 'en', 'giftet')
# ('var', 'en', 'granarna')
# ('var', 'en', 'granmaskarna')
# ('var', 'en', 'granskogen')
# ('var', 'en', 'glest')
# ('var', 'en', 'gnagde')
# ('var', 'en', 'granen')
# ('var', 'en', 'gläfste')
# ('var', 'en', 'gnager')
# ('var', 'en', 'gärdat')
# ('var', 'en', 'gärdsgårdarna')
# ('var', 'en', 'genaste')
# ('var', 'en', 'grannskogarna')
# ('var', 'en', 'gränsskogarna')
# ('var', 'en', 'gamlefar')
# ('var', 'en', 'gåsmor')
# ('var', 'en', 'gärdsgårdar')
# ('var', 'en', 'gnistor')
# ('var', 'en', 'gnuggar')
# ('var', 'en', 'glöda')
# ('var', 'en', 'grindarna')
# ('var', 'en', 'gräskanten')
# ('var', 'en', 'grunda')
# ('var', 'en', 'gipsade')
# ('var', 'en', 'gubben')
# ('var', 'en', 'gravvårdar')
# ('var', 'en', 'grämelse')
# ('var', 'en', 'gripsholm')
# ('var', 'en', 'gladare')
# ('var', 'en', 'gallergluggar')
# ('var', 'en', 'gallergrinden')
# ('var', 'en', 'grinden')
# ('var', 'en', 'gallerverket')
# ('var', 'en', 'gestalten')
# ('var', 'en', 'glanshammar')
# ('var', 'en', 'grönsaksskutor')
# ('var', 'en', 'gäckande')
# ('var', 'en', 'gästgivargården')
# ('var', 'en', 'grunt')
# ('var', 'en', 'gästgivargård')
# ('var', 'en', 'galen')
# ('var', 'en', 'grymt')
# ('var', 'en', 'gathörn')
# ('var', 'en', 'gruvligt')
# ('var', 'en', 'gråten')
# ('var', 'en', 'gråt')
# ('var', 'en', 'gårdagsregnet')
# ('var', 'en', 'göt')
# ('var', 'en', 'göksholmslandet')
# ('var', 'en', 'gräto')
# ('var', 'en', 'gruvstegarna')
# ('var', 'en', 'grusbankar')
# ('var', 'en', 'gråstenshällar')
# ('var', 'en', 'getter')
# ('var', 'en', 'gammalmoran')
# ('var', 'en', 'genomsprängd')
# ('var', 'en', 'gåshalsen')
# ('var', 'en', 'gnisslade')
# ('var', 'en', 'gnissel')
# ('var', 'en', 'gruva')
# ('var', 'en', 'granskogsåsarna')
# ('var', 'en', 'grannskapet')
# ('var', 'en', 'gnistblandad')
# ('var', 'en', 'gruvfält')
# ('var', 'en', 'genomborrad')
# ('var', 'en', 'gruvhål')
# ('var', 'en', 'gruvskotten')
# ('var', 'en', 'gruvgången')
# ('var', 'en', 'genomtrött')
# ('var', 'en', 'glimmande')
# ('var', 'en', 'gruvstöten')
# ('var', 'en', 'garpenberg')
# ('var', 'en', 'grannskap')
# ('var', 'en', 'gluggar')
# ('var', 'en', 'gnistorna')
# ('var', 'en', 'glödande')
# ('var', 'en', 'grytan')
# ('var', 'en', 'grubbla')
# ('var', 'en', 'grubblat')
# ('var', 'en', 'grängesbergs')
# ('var', 'en', 'grängshammars')
# ('var', 'en', 'grävde')
# ('var', 'en', 'grövelån')
# ('var', 'en', 'grövelsjön')
# ('var', 'en', 'görälven')
# ('var', 'en', 'gagnef')
# ('var', 'en', 'gesundaberget')
# ('var', 'en', 'gårdsplan')
# ('var', 'en', 'gruvstaden')
# ('var', 'en', 'genomflytes')
# ('var', 'en', 'grönskande')
# ('var', 'en', 'gruvkonster')
# ('var', 'en', 'grubbel')
# ('var', 'en', 'gruvfältet')
# ('var', 'en', 'gruvhusen')
# ('var', 'en', 'gruvbäck')
# ('var', 'en', 'glugglucka')
# ('var', 'en', 'grytor')
# ('var', 'en', 'glugg')
# ('var', 'en', 'gråstrimmiga')
# ('var', 'en', 'gagn')
# ('var', 'en', 'gnaga')
# ('var', 'en', 'gudstjänsten')
# ('var', 'en', 'gästfrihet')
# ('var', 'en', 'gruvhackor')
# ('var', 'en', 'gruvschakt')
# ('var', 'en', 'gruvgångarna')
# ('var', 'en', 'gruvdrängarna')
# ('var', 'en', 'genomströva')
# ('var', 'en', 'gruvdrängar')
# ('var', 'en', 'gruvarbete')
# ('var', 'en', 'gruvfogde')
# ('var', 'en', 'gästabud')
# ('var', 'en', 'gräl')
# ('var', 'en', 'gruvöppningen')
# ('var', 'en', 'grycksbo')
# ('var', 'en', 'glänste')
# ('var', 'en', 'grader')
# ('var', 'en', 'glödröda')
# ('var', 'en', 'guldsmycken')
# ('var', 'en', 'gläds')
# ('var', 'en', 'gammalfolk')
# ('var', 'en', 'gatstenarna')
# ('var', 'en', 'gärdet')
# ('var', 'en', 'gifte')
# ('var', 'en', 'go')
# ('var', 'en', 'gustav')
# ('var', 'en', 'gudstjänst')
# ('var', 'en', 'grupper')
# ('var', 'en', 'gossarna')
# ('var', 'en', 'gammalfolket')
# ('var', 'en', 'gravar')
# ('var', 'en', 'gudstjänstens')
# ('var', 'en', 'guldkrona')
# ('var', 'en', 'granskogarna')
# ('var', 'en', 'garn')
# ('var', 'en', 'grepos')
# ('var', 'en', 'grållingar')
# ('var', 'en', 'gåsraden')
# ('var', 'en', 'gåskungen')
# ('var', 'en', 'gåskarln')
# ('var', 'en', 'gods')
# ('var', 'en', 'gråter')
# ('var', 'en', 'gåvorna')
# ('var', 'en', 'gåvor')
# ('var', 'en', 'glimt')
# ('var', 'en', 'genmält')
# ('var', 'en', 'gustavianum')
# ('var', 'en', 'glasögon')
# ('var', 'en', 'guldbroderade')
# ('var', 'en', 'grantoppar')
# ('var', 'en', 'gnuggat')
# ('var', 'en', 'gästat')
# ('var', 'en', 'glädjens')
# ('var', 'en', 'gingos')
# ('var', 'en', 'genomskinliga')
# ('var', 'en', 'grundvalar')
# ('var', 'en', 'guldöga')
# ('var', 'en', 'gässlingar')
# ('var', 'en', 'gåsbonden')
# ('var', 'en', 'galning')
# ('var', 'en', 'gubbe')
# ('var', 'en', 'glasskåp')
# ('var', 'en', 'glam')
# ('var', 'en', 'glittrade')
# ('var', 'en', 'gråbröder')
# ('var', 'en', 'gråmunkeholmen')
# ('var', 'en', 'grott')
# ('var', 'en', 'galgbacke')
# ('var', 'en', 'göran')
# ('var', 'en', 'gränderna')
# ('var', 'en', 'gråmunkarnas')
# ('var', 'en', 'gravplats')
# ('var', 'en', 'glittra')
# ('var', 'en', 'gåsredet')
# ('var', 'en', 'grodor')
# ('var', 'en', 'gåsunge')
# ('var', 'en', 'gåsungarna')
# ('var', 'en', 'gyckel')
# ('var', 'en', 'glanslösa')
# ('var', 'en', 'gryningsstrimman')
# ('var', 'en', 'gröt')
# ('var', 'en', 'grönskade')
# ('var', 'en', 'gästrikland')
# ('var', 'en', 'greppet')
# ('var', 'en', 'gunst')
# ('var', 'en', 'granriskjortel')
# ('var', 'en', 'gråstenströja')
# ('var', 'en', 'glammet')
# ('var', 'en', 'getporsen')
# ('var', 'en', 'granfrön')
# ('var', 'en', 'grepo')
# ('var', 'en', 'gröda')
# ('var', 'en', 'grendalar')
# ('var', 'en', 'gräns')
# ('var', 'en', 'grendalarna')
# ('var', 'en', 'glädjedag')
# ('var', 'en', 'granskade')
# ('var', 'en', 'gastar')
# ('var', 'en', 'get')
# ('var', 'en', 'grepp')
# ('var', 'en', 'glesare')
# ('var', 'en', 'granriskappa')
# ('var', 'en', 'grankotthår')
# ('var', 'en', 'getterna')
# ('var', 'en', 'gärningen')
# ('var', 'en', 'gropig')
# ('var', 'en', 'gamman')
# ('var', 'en', 'grannens')
# ('var', 'en', 'grenklyka')
# ('var', 'en', 'gevärssalvor')
# ('var', 'en', 'glödde')
# ('var', 'en', 'getpors')
# ('var', 'en', 'genomskuret')
# ('var', 'en', 'granskat')
# ('var', 'en', 'gorgos')
# ('var', 'en', 'grindar')
# ('var', 'en', 'glesa')
# ('var', 'en', 'guldregn')
# ('var', 'en', 'gotlandskyrkorna')
# ('var', 'en', 'gullkragar')
# ('var', 'en', 'guldskiftningar')
# ('var', 'en', 'gåspar')
# ('var', 'en', 'graven')
# ('var', 'en', 'gravöl')
# ('var', 'en', 'gåtan')
# ('var', 'en', 'genomföra')
# ('var', 'en', 'gellivare')
# ('var', 'en', 'glödlampor')
# ('var', 'en', 'genomdrivet')
# ('var', 'en', 'gruvförmännen')
# ('var', 'en', 'gruvtrakten')
# ('var', 'en', 'godtemplarsalen')
# ('var', 'en', 'gruvarbetarhustrur')
# ('var', 'en', 'granris')
# ('var', 'en', 'gruvschakten')
# ('var', 'en', 'grupp')
# ('var', 'en', 'gruvorna')
# ('var', 'en', 'gåsapigas')
# ('var', 'en', 'gångna')
# ('var', 'en', 'gryta')
# ('var', 'en', 'gruståg')
# ('var', 'en', 'grånat')
# ('var', 'en', 'gruvstäderna')
# ('var', 'en', 'gruvöppning')
# ('var', 'en', 'geten')
# ('var', 'en', 'grunder')
# ('var', 'en', 'gästen')
# ('var', 'en', 'gröten')
# ('var', 'en', 'gala')
# ('var', 'en', 'genmälde')
# ('var', 'en', 'granruskorna')
# ('var', 'en', 'gråbenen')
# ('var', 'en', 'gråben')
# ('var', 'en', 'gjordarna')
# ('var', 'en', 'gränsar')
# ('var', 'en', 'gravhög')
# ('var', 'en', 'ges')
# ('var', 'en', 'glöm')
# ('var', 'en', 'grälar')
# ('var', 'en', 'glafsfjorden')
# ('var', 'en', 'gavs')
# ('var', 'en', 'glesnade')
# ('var', 'en', 'grönsakslanden')
# ('var', 'en', 'gräskant')
# ('var', 'en', 'grusgångar')
# ('var', 'en', 'gråskinn')
# ('var', 'en', 'gifttand')
# ('var', 'en', 'gråna')
# ('var', 'en', 'gaveln')
# ('var', 'en', 'grammatik')
# ('var', 'en', 'gitarr')
# ('var', 'en', 'gåsrygg')
# ('var', 'en', 'gåskätten')
# ('var', 'en', 'guldband')
# ('var', 'en', 'gulvita')
# ('var', 'en', 'gåva')
# ('var', 'en', 'gråstenshäll')
# ('var', 'en', 'guldstycken')
# ('var', 'en', 'guldmynten')
# ('var', 'en', 'götaälv')
# ('var', 'en', 'gemensam')
# ('var', 'en', 'gungande')
# ('var', 'en', 'gulaktig')
# ('var', 'en', 'glättighet')
# ('var', 'en', 'gymnastikövning')
# ('var', 'en', 'gårdens')
# ('var', 'en', 'gåve')
# ('var', 'en', 'gymnastiksal')
# ('var', 'en', 'gagna')
# ('var', 'en', 'gymnastiserade')
# ('var', 'en', 'genomvärmd')
# ('var', 'en', 'gäst')
# ('var', 'en', 'glädjeämnen')
# ('var', 'en', 'genomvärmdes')
# ('var', 'en', 'gruset')
# ('var', 'en', 'glödhett')
# ('var', 'en', 'gemensamma')
# ('var', 'en', 'grusa')
# ('var', 'en', 'gråstensberg')
# ('var', 'en', 'gullöfallet')
# ('var', 'en', 'götaälvs')
# ('var', 'en', 'genmäle')
# ('var', 'en', 'göteborg')
# ('var', 'en', 'gästvänskap')
# ('var', 'en', 'given')
# ('var', 'en', 'gymnastiklokalen')
# ('var', 'en', 'gräshoppas')
# ('var', 'en', 'grimön')
# ('var', 'en', 'gödsel')
# ('var', 'en', 'godmodigt')
# ('var', 'en', 'glädjestunder')
# ('var', 'en', 'grimöpojke')
# ('var', 'en', 'graden')
# ('var', 'en', 'gråtande')
# ('var', 'en', 'grinande')
# ('var', 'en', 'grymheter')
# ('var', 'en', 'göres')
# ('var', 'en', 'genomträngde')
# ('var', 'en', 'grimöfolket')
# ('var', 'en', 'gråbergsmur')
# ('var', 'en', 'grannlåtshus')
# ('var', 'en', 'grannstugorna')
# ('var', 'en', 'grönstrimmiga')
# ('var', 'en', 'glåpord')
# ('var', 'en', 'glättig')
# ('var', 'en', 'godmodiga')
# ('var', 'en', 'grovt')
# ('var', 'en', 'gällare')
# ('var', 'en', 'godvilligt')
# ('var', 'en', 'gåvos')
# ('var', 'en', 'gångs')
# ('var', 'en', 'garnen')
# ('var', 'en', 'grundläggning')
# ('var', 'en', 'grundläggare')
# ('var', 'en', 'granitsockel')
# ('var', 'en', 'gunnar')
# ('var', 'en', 'gymnastikapparater')
# ('var', 'en', 'gardinerna')
# ('var', 'en', 'gripande')
# ('var', 'en', 'genomgångar')
# ('var', 'en', 'gynnad')
# ('var', 'en', 'gråvioletta')
# ('var', 'en', 'gråstensklyftorna')
# ('var', 'en', 'giriga')
# ('var', 'en', 'godsägare')
# ('var', 'en', 'gränslöst')
# ('var', 'en', 'genljödo')
# ('var', 'en', 'glåmiga')
# ('var', 'en', 'grymtade')
# ('var', 'en', 'gnista')
# ('var', 'en', 'gulvitt')
# ('var', 'en', 'grundvalen')
# ('var', 'en', 'gustava')
# ('var', 'en', 'grötskovor')
# ('var', 'en', 'grytbottnen')
# ('var', 'en', 'grimas')
# ('var', 'en', 'gallren')
# ('var', 'en', 'gifter')
# ('var', 'en', 'grundligt')
# ('var', 'en', 'giftermålsanbud')
# ('var', 'en', 'genomforo')
# ('var', 'en', 'gästabudsmaten')
# ('var', 'en', 'gaffel')
# ('var', 'en', 'gladlynt')
# ('var', 'en', 'genomskinligt')
# ('var', 'en', 'grindstolpen')
# ('var', 'en', 'grindstolpe')
# ('var', 'en', 'genomlevat')
# ('var', 'en', 'glasögonen')
# ('var', 'en', 'gudar')
# ('var', 'en', 'genomblöta')
# ('var', 'en', 'gestalt')
# ('var', 'en', 'gråblekt')
# ('var', 'en', 'gånget')
# ('var', 'en', 'gårdsdrängen')
# ('var', 'en', 'gårdsdrängens')
# ('var', 'en', 'gårdagen')
# ('var', 'en', 'gestaltens')
# ('var', 'en', 'genomgick')
# ('var', 'en', 'galler')
# ('var', 'en', 'gustavsson')
# ('var', 'en', 'gästgivarns')
# ('var', 'en', 'gästrum')
# ('var', 'en', 'giftermålet')
# ('var', 'en', 'gungstolsdyna')
# ('var', 'en', 'gungstolsdynan')
# ('var', 'en', 'gjutit')
# ('var', 'en', 'grannfar')
# ('var', 'en', 'grannmor')
# ('var', 'en', 'gällande')
# ('var', 'en', 'gränsskogen')
# ('var', 'en', 'gräslighet')
# ('var', 'en', 'gästfria')
# ('var', 'en', 'gamles')
# ('var', 'en', 'grannen')
# ('var', 'en', 'guldglans')
# ('var', 'en', 'granhäck')
# ('var', 'en', 'granrishäcken')
# ('var', 'en', 'gäckeri')
# ('var', 'en', 'gest')
# ('var', 'en', 'genomför')
# ('var', 'en', 'gynnsamma')
# ('var', 'en', 'genomströmmade')
# ('var', 'en', 'genomisades')
# ('var', 'en', 'gravjungfru')
# ('var', 'en', 'granhäcken')
# ('var', 'en', 'gästernas')
# ('var', 'en', 'gevär')
# ('var', 'en', 'gränden')
# ('var', 'en', 'gångerna')
# ('var', 'en', 'garnmaskor')
# ('var', 'en', 'genomgå')
# ('var', 'en', 'genomträngd')
# ('var', 'en', 'gatans')
# ('var', 'en', 'genomlevde')
# ('var', 'en', 'gräsmattan')
# ('var', 'en', 'gapar')
# ('var', 'en', 'gråbleka')
# ('var', 'en', 'glädjesprång')
# ('var', 'en', 'glömda')
# ('var', 'en', 'givits')
# ('var', 'en', 'gripen')
# ('var', 'en', 'genomgått')
# ('var', 'en', 'glädjas')
# ('var', 'en', 'gräsplanen')
# ('var', 'en', 'grof')
# ('var', 'en', 'gustaf')
# ('var', 'en', 'gifvande')
# ('var', 'en', 'grufvan')
# ('var', 'en', 'gladt')
# ('var', 'en', 'galenskaper')
# ('var', 'en', 'gaf')
# ('var', 'en', 'granskning')
# ('var', 'en', 'gaskjolar')
# ('var', 'en', 'gårdfarihandel')
# ('var', 'en', 'guldkaret')
# ('var', 'en', 'grufva')
# ('var', 'en', 'gruffält')
# ('var', 'en', 'granskogsklädda')
# ('var', 'en', 'gubbens')
# ('var', 'en', 'godt')
# ('var', 'en', 'gifvit')
# ('var', 'en', 'gårdfarihandlande')
# ('var', 'en', 'genomströfva')
# ('var', 'en', 'getskara')
# ('var', 'en', 'grafven')
# ('var', 'en', 'grafkanten')
# ('var', 'en', 'gestalterna')
# ('var', 'en', 'gnistrade')
# ('var', 'en', 'grimmor')
# ('var', 'en', 'getabockar')
# ('var', 'en', 'getabocken')
# ('var', 'en', 'grofva')
# ('var', 'en', 'getskinn')
# ('var', 'en', 'graf')
# ('var', 'en', 'gåfva')
# ('var', 'en', 'glömdt')
# ('var', 'en', 'grafväggen')
# ('var', 'en', 'grafändan')
# ('var', 'en', 'gröngräset')
# ('var', 'en', 'graföppningen')
# ('var', 'en', 'galne')
# ('var', 'en', 'grafvarna')
# ('var', 'en', 'graföl')
# ('var', 'en', 'greta')
# ('var', 'en', 'galningen')
# ('var', 'en', 'gastgrå')
# ('var', 'en', 'grafölet')
# ('var', 'en', 'grymmare')
# ('var', 'en', 'gudsord')
# ('var', 'en', 'gengångare')
# ('var', 'en', 'grankvist')
# ('var', 'en', 'gräsbevuxen')
# ('var', 'en', 'grämde')
# ('var', 'en', 'golfven')
# ('var', 'en', 'gömdt')
# ('var', 'en', 'gåfvor')
# ('var', 'en', 'gjordt')
# ('var', 'en', 'glammade')
# ('var', 'en', 'graflilja')
# ('var', 'en', 'gustafva')
# ('var', 'en', 'getabock')
# ('var', 'en', 'gångstig')
# ('var', 'en', 'gråblek')
# ('var', 'en', 'glädjebål')
# ('var', 'en', 'glömska')
# ('var', 'en', 'gräfde')
# ('var', 'en', 'gräfningen')
# ('var', 'en', 'gissande')
# ('var', 'en', 'gräfva')
# ('var', 'en', 'gärdesgård')
# ('var', 'en', 'gångbara')
# ('var', 'en', 'gångbar')
# ('var', 'en', 'gökrop')
# ('var', 'en', 'glansen')
# ('var', 'en', 'glänsa')
# ('var', 'en', 'gästgifvargård')
# ('var', 'en', 'gästgifvaregården')
# ('var', 'en', 'gästrummen')
# ('var', 'en', 'gästgifvarn')
# ('var', 'en', 'galmanstankarna')
# ('var', 'en', 'gästgifvargården')
# ('var', 'en', 'gästgifvargårdens')
# ('var', 'en', 'gästrumsfönstren')
# ('var', 'en', 'gehör')
# ('var', 'en', 'gymnasist')
# ('var', 'en', 'galmansblicken')
# ('var', 'en', 'galenskapen')
# ('var', 'en', 'gardin')
# ('var', 'en', 'genomvandrat')
# ('var', 'en', 'genomströmmades')
# ('var', 'en', 'groddammen')
# ('var', 'en', 'gullebarn')
# ('var', 'en', 'gladaste')
# ('var', 'en', 'gråsvarta')
# ('var', 'en', 'grästuvorna')
# ('var', 'en', 'grynkaka')
# ('var', 'en', 'gårds')
# ('var', 'en', 'gjordar')
# ('var', 'en', 'gärdesgårdarna')
# ('var', 'en', 'gulhyade')
# ('var', 'en', 'grävningen')
# ('var', 'en', 'gårdsledet')
# ('var', 'en', 'glädjekänsla')
# ('var', 'en', 'gammalmora')
# ('var', 'en', 'gammalmoras')
# ('var', 'en', 'glör')
# ('var', 'en', 'gräsbacken')
# ('var', 'en', 'galenskap')
# ('var', 'en', 'gammalmodiga')
# ('var', 'en', 'gravkorsen')
# ('var', 'en', 'gravmull')
# ('var', 'en', 'gudaktighet')
# ('var', 'en', 'grästorva')
# ('var', 'en', 'gravkulle')
# ('var', 'en', 'grästorvan')
# ('var', 'en', 'gravmullen')
# ('var', 'en', 'gast')
# ('var', 'en', 'glappade')
# ('var', 'en', 'gudaktigt')
# ('var', 'en', 'grannsocknen')
# ('var', 'en', 'gnisslet')
# ('var', 'en', 'genomfors')
# ('var', 'en', 'gläntade')
# ('var', 'en', 'glittrat')
# ('var', 'en', 'grenverket')
# ('var', 'en', 'glesnat')
# ('var', 'en', 'gräsrika')
# ('var', 'en', 'grundvattnet')
# ('var', 'en', 'gilles')
# ('var', 'en', 'genomtänkt')
# ('var', 'en', 'gnissla')
# ('var', 'en', 'görs')
# ('var', 'en', 'gamlingen')
# ('var', 'en', 'godsets')
# ('var', 'en', 'gärden')
# ('var', 'en', 'gäck')
# ('var', 'en', 'gagnlöst')
# ('var', 'en', 'grodd')
# ('var', 'en', 'grovlemmad')
# ('var', 'en', 'gravdyster')
# ('var', 'en', 'grubblar')
# ('var', 'en', 'glädjeyra')
# ('var', 'en', 'gräsens')
# ('var', 'en', 'giver')
# ('var', 'en', 'grina')
# ('var', 'en', 'glimma')
# ('var', 'en', 'grönsakskorgar')
# ('var', 'en', 'gudsmannen')
# ('var', 'en', 'gyckelmakare')
# ('var', 'en', 'gycklet')
# ('var', 'en', 'granne')
# ('var', 'en', 'galärslav')
# ('var', 'en', 'galärslaven')
# ('var', 'en', 'gudshuset')
# ('var', 'en', 'grannes')
# ('var', 'en', 'garnände')
# ('var', 'en', 'glasram')
# ('var', 'en', 'gehänget')
# ('var', 'en', 'gångstigarna')
# ('var', 'en', 'gårdsfogde')
# ('var', 'en', 'gälda')
# ('var', 'en', 'gungbräde')
# ('var', 'en', 'gösta')
# ('var', 'en', 'genljud')
# ('var', 'en', 'genvägen')
# ('var', 'en', 'gymnastiskt')
# ('var', 'en', 'guvernanten')
# ('var', 'en', 'guldstoft')
# ('var', 'en', 'gudagåvan')
# ('var', 'en', 'guvernantsplats')
# ('var', 'en', 'grannförsamling')
# ('var', 'en', 'glider')
# ('var', 'en', 'glede')
# ('var', 'en', 'gungstolen')
# ('var', 'en', 'gäldas')
# ('var', 'en', 'geijerstams')
# ('var', 'en', 'gesällvandring')
# ('var', 'en', 'glädjetårarna')
# ('var', 'en', 'genomföras')
# ('var', 'en', 'gestalter')
# ('var', 'en', 'gyllenstierna')
# ('var', 'en', 'gödda')
# ('var', 'en', 'gulnande')
# ('var', 'en', 'gosskolan')
# ('var', 'en', 'genvägar')
# ('var', 'en', 'guden')
# ('var', 'en', 'gymnasiet')
# ('var', 'en', 'gossar')
# ('var', 'en', 'gärningar')
# ('var', 'en', 'gottlandstidning')
# ('var', 'en', 'gripna')
# ('var', 'en', 'glädjelöshetens')
# ('var', 'en', 'glömskans')
# ('var', 'en', 'gagnlösa')
# ('var', 'en', 'guvernörshuset')
# ('var', 'en', 'guvernörsdottern')
# ('var', 'en', 'guvernör')
# ('var', 'en', 'generaln')
# ('var', 'en', 'general')
# ('var', 'en', 'glittrar')
# ('var', 'en', 'glimten')
# ('var', 'en', 'girigt')
# ('var', 'en', 'giftormar')
# ('var', 'en', 'gästabuden')
# ('var', 'en', 'gästerna')
# ('var', 'en', 'gästabudet')
# ('var', 'en', 'geni')
# ('var', 'en', 'grävda')
# ('var', 'en', 'gräsvallen')
# ('var', 'en', 'gårdskusken')
# ('var', 'en', 'gamlefars')
# ('var', 'en', 'gråstensmuren')
# ('var', 'en', 'gångstigen')
# ('var', 'en', 'goafton')
# ('var', 'en', 'gästabudsväg')
# ('var', 'en', 'golvtiljor')
# ('var', 'en', 'genomgång')
# ('var', 'en', 'grenljus')
# ('var', 'en', 'glaset')
# ('var', 'en', 'gavelrum')
# ('var', 'en', 'gråtandet')
# ('var', 'en', 'genomgångna')
# ('var', 'en', 'gårdsägarna')
# ('var', 'en', 'gynnsam')
# ('var', 'en', 'gummorna')
# ('var', 'en', 'grädde')
# ('var', 'en', 'grannkvinnorna')
# ('var', 'en', 'gilla')
# ('var', 'en', 'girig')
# ('var', 'en', 'genomfart')
# ('var', 'en', 'gudsfruktan')
# ('var', 'en', 'giftermål')
# ('var', 'en', 'genomträngt')
# ('var', 'en', 'genomskinlighet')
# ('var', 'en', 'gemål')
# ('var', 'en', 'gullstol')
# ('var', 'en', 'givande')
# ('var', 'en', 'galit')
# ('var', 'en', 'genomskimrades')
# ('var', 'en', 'genomleva')
# ('var', 'en', 'gatlopp')
# ('var', 'en', 'gravkammaren')
# ('var', 'en', 'genomskar')
# ('var', 'en', 'genomvandrade')
# ('var', 'en', 'glädjebringande')
# ('var', 'en', 'gästabudssalen')
# ('var', 'en', 'genomskådande')
# ('var', 'en', 'gullspångsälven')
# ('var', 'en', 'glömskan')
# ('var', 'en', 'generaler')
# ('var', 'en', 'gestikulera')
# ('var', 'en', 'gruppen')
# ('var', 'en', 'genomborrat')
# ('var', 'en', 'gendriva')
# ('var', 'en', 'gunstling')
# ('var', 'en', 'gästgiverska')
# ('var', 'en', 'grönsakshandlerska')
# ('var', 'en', 'givna')
# ('var', 'en', 'greve')
# ('var', 'en', 'gratulerat')
# ('var', 'en', 'graciös')
# ('var', 'en', 'glöd')
# ('var', 'en', 'genomsökte')
# ('var', 'en', 'gäng')
# ('var', 'en', 'genomträngdes')
# ('var', 'en', 'gudomligt')
# ('var', 'en', 'gudomliga')
# ('var', 'en', 'gulla')
# ('var', 'en', 'godda')
# ('var', 'en', 'goafta')
# ('var', 'en', 'genomskära')
# ('var', 'en', 'genomlöpte')
# ('var', 'en', 'gråvit')
# ('var', 'en', 'genljudit')
# ('var', 'en', 'genomtränga')
# ('var', 'en', 'galavagn')
# ('var', 'en', 'gravkamrar')
# ('var', 'en', 'grekisk')
# ('var', 'en', 'glömmas')
# ('var', 'en', 'gravhuset')
# ('var', 'en', 'grifthuset')
# ('var', 'en', 'griften')
# ('var', 'en', 'genomgrävda')
# ('var', 'en', 'gluggarna')
# ('var', 'en', 'gagnlös')
# ('var', 'en', 'gudshusen')
# ('var', 'en', 'genljuda')
# ('var', 'en', 'gycklare')
# ('var', 'en', 'genomströvade')
# ('var', 'en', 'grönskan')
# ('var', 'en', 'gossaktiga')
# ('var', 'en', 'glädjelös')
# ('var', 'en', 'griper')
# ('var', 'en', 'glädjestund')
# ('var', 'en', 'gungar')
# ('var', 'en', 'granater')
# ('var', 'en', 'grymheten')
# ('var', 'en', 'gellerstedt')
# ('var', 'en', 'gellerstedtska')
# ('var', 'en', 'gränsbo')
# ('var', 'en', 'gärdesgården')
# ('var', 'en', 'guldvivor')
# ('var', 'en', 'gredelina')
# ('var', 'en', 'grävaren')
# ('var', 'en', 'grubblas')
# ('var', 'en', 'gellerstedts')
# ('var', 'en', 'grändernas')
# ('var', 'en', 'gåtor')
# ('var', 'en', 'gulbröstad')
# ('var', 'en', 'giva')
# ('var', 'en', 'gummas')
# ('var', 'en', 'glitterstånden')
# ('var', 'en', 'gjuter')
# ('var', 'en', 'glädjefanor')
# ('var', 'en', 'garnet')
# ('var', 'en', 'gråterskor')
# ('var', 'en', 'gråterskorna')
# ('var', 'en', 'glammandes')
# ('var', 'en', 'guldharpan')
# ('var', 'en', 'gubbeträta')
# ('var', 'en', 'göto')
# ('var', 'en', 'glammen')
# ('var', 'en', 'glömden')
# ('var', 'en', 'genomglödgat')
# ('var', 'en', 'guldkorset')
# ('var', 'en', 'grannförsamlingarna')
# ('var', 'en', 'gravölet')
# ('var', 'en', 'gästgivargårdens')
# ('var', 'en', 'grannfruarna')
# ('var', 'en', 'gode')
# ('var', 'en', 'gurlita')
# ('var', 'en', 'galnaste')
# ('var', 'en', 'galopp')
# ('var', 'en', 'give')
# ('var', 'en', 'gnisslar')
# ('var', 'en', 'gästgivarmor')
# ('var', 'en', 'gravkullarna')
# ('var', 'en', 'gillen')
# ('var', 'en', 'gästade')
# ('var', 'en', 'gäckat')
# ('var', 'en', 'grevens')
# ('var', 'en', 'gråstensmurar')
# ('var', 'en', 'gråstensrygg')
# ('var', 'en', 'granpäls')
# ('var', 'en', 'grälaktiga')
# ('var', 'en', 'glädes')
# ('var', 'en', 'generalbas')
# ('var', 'en', 'giktbrutne')
# ('var', 'en', 'genljuder')
# ('var', 'en', 'glimmar')
# ('var', 'en', 'gudars')
# ('var', 'en', 'glasen')
# ('var', 'en', 'göstas')
# ('var', 'en', 'grevinnan')
# ('var', 'en', 'gudaglansen')
# ('var', 'en', 'gatpojke')
# ('var', 'en', 'grannars')
# ('var', 'en', 'grannsocknarna')
# ('var', 'en', 'gåspenna')
# ('var', 'en', 'greven')
# ('var', 'en', 'gläd')
# ('var', 'en', 'grevinna')
# ('var', 'en', 'grevegården')
# ('var', 'en', 'gratulera')
# ('var', 'en', 'glade')
# ('var', 'en', 'gnistrande')
# ('var', 'en', 'gulrutiga')
# ('var', 'en', 'gemak')
# ('var', 'en', 'giktplågor')
# ('var', 'en', 'gördel')
# ('var', 'en', 'gikten')
# ('var', 'en', 'grace')
# ('var', 'en', 'granadas')
# ('var', 'en', 'gitanas')
# ('var', 'en', 'guldglänsande')
# ('var', 'en', 'glorian')
# ('var', 'en', 'genomilade')
# ('var', 'en', 'glänst')
# ('var', 'en', 'greveslotten')
# ('var', 'en', 'grevekronor')
# ('var', 'en', 'gladdes')
# ('var', 'en', 'gallret')
# ('var', 'en', 'grimaserande')
# ('var', 'en', 'genomborra')
# ('var', 'en', 'gudinna')
# ('var', 'en', 'gnid')
# ('var', 'en', 'gästrummet')
# ('var', 'en', 'grästorvor')
# ('var', 'en', 'gräshoppor')
# ('var', 'en', 'gamlas')
# ('var', 'en', 'gripar')
# ('var', 'en', 'gudinnor')
# ('var', 'en', 'gardinsnöret')
# ('var', 'en', 'genomisade')
# ('var', 'en', 'gästgivargårdarnas')
# ('var', 'en', 'glanskis')
# ('var', 'en', 'genklang')
# ('var', 'en', 'gripas')
# ('var', 'en', 'göpa')
# ('var', 'en', 'göken')
# ('var', 'en', 'gal')
# ('var', 'en', 'gemåls')
# ('var', 'en', 'gäldbunden')
# ('var', 'en', 'girighet')
# ('var', 'en', 'gurlitabjörnen')
# ('var', 'en', 'genomforskats')
# ('var', 'en', 'gulblekare')
# ('var', 'en', 'grundlig')
# ('var', 'en', 'gillande')
# ('var', 'en', 'gustavas')
# ('var', 'en', 'gnuggade')
# ('var', 'en', 'gur')
# ('var', 'en', 'gulgröna')
# ('var', 'en', 'gårdshunden')
# ('var', 'en', 'gårdsfogden')
# ('var', 'en', 'genstörtig')
# ('var', 'en', 'genomskådat')
# ('var', 'en', 'gulnat')
# ('var', 'en', 'grevinnans')
# ('var', 'en', 'gåsöga')
# ('var', 'en', 'gammalmanshuvud')
# ('var', 'en', 'guldkanter')
# ('var', 'en', 'genomjagad')
# ('var', 'en', 'gallerfönster')
# ('var', 'en', 'golvets')
# ('var', 'en', 'gören')
# ('var', 'en', 'gästabudets')
# ('var', 'en', 'glitter')
# ('var', 'en', 'granskogens')
# ('var', 'en', 'gärningarnas')
# ('var', 'en', 'gungstolar')
# ('var', 'en', 'gravstenen')
# ('var', 'en', 'golvtiljan')
# ('var', 'en', 'gapskratt')
# ('var', 'en', 'genomfårade')
# ('var', 'en', 'gräsligheter')
# ('var', 'en', 'godmodighet')
# ('var', 'en', 'golvplankorna')
# ('var', 'en', 'glättade')
# ('var', 'en', 'genomsöka')
# ('var', 'en', 'granparkens')
# ('var', 'en', 'garnhärva')
# ('var', 'en', 'grevedotter')
# ('var', 'en', 'gravarna')
# ('var', 'en', 'grevedotterns')
# ('var', 'en', 'genomkyla')
# ('var', 'en', 'gulröd')
# ('var', 'en', 'gillesmat')
# ('var', 'en', 'gängor')
# ('var', 'en', 'grönland')
# ('var', 'en', 'gräslisten')
# ('var', 'en', 'gärdsgårdens')
# ('var', 'en', 'glaspärlor')
# ('var', 'en', 'girlander')
# ('var', 'en', 'glasäpplena')
# ('var', 'en', 'gitarren')
# ('var', 'en', 'gitarrbandet')
# ('var', 'en', 'grevinnorna')
# ('var', 'en', 'genierna')
# ('var', 'en', 'gölar')
# ('var', 'en', 'gråstenstrappa')
# ('var', 'en', 'glömmande')
# ('var', 'en', 'grip')
# ('var', 'en', 'grälat')
# ('var', 'en', 'gravhällarna')
# ('var', 'en', 'gisslet')
# ('var', 'en', 'gammalmanshuvudet')
# ('var', 'en', 'gisslets')
# ('var', 'en', 'glädjeämne')
# ('var', 'en', 'grevar')
# ('var', 'en', 'glömd')
# ('var', 'en', 'griftetal')
# ('var', 'en', 'granskogarnas')
# ('var', 'en', 'glöden')
# ('var', 'en', 'grosshandelskontoren')
# ('var', 'en', 'göm')
# ('var', 'en', 'grosshandlarna')
# ('var', 'en', 'grovhugget')
# ('var', 'en', 'gungbrädet')
# ('var', 'en', 'gräsplan')
# ('var', 'en', 'grantopparna')
# ('var', 'en', 'gödslat')
# ('var', 'en', 'gullhornade')
# ('var', 'en', 'genomströvar')
# ('var', 'en', 'gömmes')
# ('var', 'en', 'gårdshundar')
# ('var', 'en', 'gudaingiven')
# ('var', 'en', 'gränsande')
# ('var', 'en', 'godhjärtad')
# ('var', 'en', 'graders')
# ('var', 'en', 'gjorts')
# ('var', 'en', 'griparna')
# ('var', 'en', 'gudinnorna')
# ('var', 'en', 'gräddvita')
# ('var', 'en', 'grumliga')
# ('var', 'en', 'genomsusade')
# ('var', 'en', 'genier')
# ('var', 'en', 'gulblek')
# ('var', 'en', 'gnäller')
# ('var', 'en', 'glänta')
# ('var', 'en', 'grevedottern')
# ('var', 'en', 'gynnade')
# ('var', 'en', 'gunstlingen')
# ('var', 'en', 'galla')
# ('var', 'en', 'giftbägaren')
# ('var', 'en', 'gomorra')
# ('var', 'en', 'gökärter')
# ('var', 'en', 'grubblare')
# ('var', 'en', 'gudom')
# ('var', 'en', 'gåta')
# ('var', 'en', 'grubblets')
# ('var', 'en', 'gagnat')
# ('var', 'en', 'glupande')
# ('var', 'en', 'guldbrämade')
# ('var', 'en', 'guldkronor')
# ('var', 'en', 'gåsfot')
# ('var', 'en', 'guldblommig')
# ('var', 'en', 'grämt')
# ('var', 'en', 'gudstjänster')
# ('var', 'en', 'gloria')
# ('var', 'en', 'gäcka')
# ('var', 'en', 'guldblommorna')
# ('var', 'en', 'gråe')
# ('var', 'en', 'galningarna')
# ('var', 'en', 'gillet')
# ('var', 'en', 'gro')
# ('var', 'en', 'gurlitafolkets')
# ('var', 'en', 'gräsets')
# ('var', 'en', 'grusade')
# ('var', 'en', 'girigbuks')
# ('var', 'en', 'granparken')
# ('var', 'en', 'gravhögar')
# ('var', 'en', 'gravens')
# ('var', 'en', 'gehäng')
# ('var', 'en', 'gunstig')
# ('var', 'en', 'genomvandra')
# ('var', 'en', 'grumlar')
# ('var', 'en', 'grumlat')
# ('var', 'en', 'granaten')
# ('var', 'en', 'godes')
# ('var', 'en', 'gästrummets')
# ('var', 'en', 'gaseller')
# ('var', 'en', 'guldvagn')
# ('var', 'en', 'guldstickad')
# ('var', 'en', 'gravkullen')
# ('var', 'en', 'gårdarnas')
# ('var', 'en', 'glädjetårar')
# ('var', 'en', 'gles')
# ('var', 'en', 'girige')
# ('var', 'en', 'grödan')
# ('var', 'en', 'greveson')
# ('var', 'en', 'giftoman')
# ('var', 'en', 'grundtonen')
# ('var', 'en', 'georginer')
# ('var', 'en', 'gäckad')
# ('var', 'en', 'gisselslag')
# ('var', 'en', 'gubbarna')
# ('var', 'en', 'granarnas')
# ('var', 'en', 'grävlingens')
# ('var', 'en', 'gruppvis')
# ('var', 'en', 'göromålen')
# ('var', 'en', 'gudlösa')
# ('var', 'en', 'gatpojkarna')
# ('var', 'en', 'gapa')
# ('var', 'en', 'grönklädda')
# ('var', 'en', 'gatpojkar')
# ('var', 'en', 'grammatikan')
# ('var', 'en', 'gesällränseln')
# ('var', 'en', 'grånade')
# ('var', 'en', 'gruvarbetarnas')
# ('var', 'en', 'gillena')
# ('var', 'en', 'gudfruktig')
# ('var', 'en', 'glanslös')
# ('var', 'en', 'grubblet')
# ('var', 'en', 'godas')
# ('var', 'en', 'grinar')
# ('var', 'en', 'grädden')
# ('var', 'en', 'gästvännen')
# ('var', 'en', 'genomvakat')
# ('var', 'en', 'gåven')
# ('var', 'en', 'gafveln')
# ('var', 'en', 'gräsgångna')
# ('var', 'en', 'grårödt')
# ('var', 'en', 'genomträngas')
# ('var', 'en', 'gåfve')
# ('var', 'en', 'grusplanen')
# ('var', 'en', 'gåfvo')
# ('var', 'en', 'golfvet')
# ('var', 'en', 'gråts')
# ('var', 'en', 'gräslig')
# ('var', 'en', 'gifvet')
# ('var', 'en', 'gråtfärdig')
# ('var', 'en', 'gertrud')
# ('var', 'en', 'grankvistar')
# ('var', 'en', 'glasbit')
# ('var', 'en', 'glasbitarna')
# ('var', 'en', 'gifva')
# ('var', 'en', 'genomdrifva')
# ('var', 'en', 'gulgrå')
# ('var', 'en', 'groft')
# ('var', 'en', 'gästgifvargårdar')
# ('var', 'en', 'gosstackarn')
# ('var', 'en', 'giftigt')
# ('var', 'en', 'grässtrån')
# ('var', 'en', 'gästgifvarsonen')
# ('var', 'en', 'göromål')
# ('var', 'en', 'gropiga')
# ('var', 'en', 'gunnars')
# ('var', 'en', 'gabriel')
# ('var', 'en', 'gunhild')
# ('var', 'en', 'gudskelof')
# ('var', 'en', 'granrisbädden')
# ('var', 'en', 'glödvarma')
# ('var', 'en', 'gertruds')
# ('var', 'en', 'gläfsande')
# ('var', 'en', 'gastars')
# ('var', 'en', 'gryningsljuset')
# ('var', 'en', 'gärdesgårdsstörar')
# ('var', 'en', 'gästgifvarens')
# ('var', 'en', 'gapskrattade')
# ('var', 'en', 'gafvel')
# ('var', 'en', 'gissade')
# ('var', 'en', 'godbit')
# ('var', 'en', 'gulblekt')
# ('var', 'en', 'gröngråa')
# ('var', 'en', 'glasruta')
# ('var', 'en', 'gordon')
# ('var', 'en', 'gränd')
# ('var', 'en', 'gunnarsdotter')
# ('var', 'en', 'gäckadt')
# ('var', 'en', 'glädtighet')
# ('var', 'en', 'gaflarna')
# ('var', 'en', 'gudfruktiga')
# ('var', 'en', 'gordons')
# ('var', 'en', 'gengåfva')
# ('var', 'en', 'genomskärning')
# ('var', 'en', 'gångmattor')
# ('var', 'en', 'genmäler')
# ('var', 'en', 'gärdsgårdsstör')
# ('var', 'en', 'gästabudsmat')
# ('var', 'en', 'gräfver')
# ('var', 'en', 'gråhvita')
# ('var', 'en', 'gabriels')
# ('var', 'en', 'garntofsar')
# ('var', 'en', 'gapade')
# ('var', 'en', 'gransnåret')
# ('var', 'en', 'giftblomster')
# ('var', 'en', 'gårdsgrinden')
# ('var', 'en', 'gåfvan')
# ('var', 'en', 'genväg')
# ('var', 'en', 'guldörhängen')
# ('var', 'en', 'genomfarit')
# ('var', 'en', 'grusplaner')
# ('var', 'en', 'grusplanerna')
# ('var', 'en', 'gehenna')
# ('var', 'en', 'gropar')
# ('var', 'en', 'galleri')
# ('var', 'en', 'gafs')
# ('var', 'en', 'gathundar')
# ('var', 'en', 'gudomlig')
# ('var', 'en', 'grundat')
# ('var', 'en', 'gordonska')
# ('var', 'en', 'grönhvita')
# ('var', 'en', 'grafvens')
# ('var', 'en', 'grågröna')
# ('var', 'en', 'genomströfvade')
# ('var', 'en', 'grönbleka')
# ('var', 'en', 'grundstenen')
# ('var', 'en', 'gnällande')
# ('var', 'en', 'grafkyrkan')
# ('var', 'en', 'golgata')
# ('var', 'en', 'gentog')
# ('var', 'en', 'gareb')
# ('var', 'en', 'genmäldes')
# ('var', 'en', 'gilgal')
# ('var', 'en', 'golf')
# ('var', 'en', 'granatäpplen')
# ('var', 'en', 'golgatas')
# ('var', 'en', 'genomväfdt')
# ('var', 'en', 'genomdränkta')
# ('var', 'en', 'grafvar')
# ('var', 'en', 'grekiska')
# ('var', 'en', 'grafkyrkans')
# ('var', 'en', 'gallerverken')
# ('var', 'en', 'grafgrottan')
# ('var', 'en', 'grekernas')
# ('var', 'en', 'gästhus')
# ('var', 'en', 'grafkyrka')
# ('var', 'en', 'gottfrid')
# ('var', 'en', 'greker')
# ('var', 'en', 'gordonisterna')
# ('var', 'en', 'gordonisternas')
# ('var', 'en', 'guldslantarna')
# ('var', 'en', 'granskande')
# ('var', 'en', 'getsemane')
# ('var', 'en', 'grafhällarna')
# ('var', 'en', 'grafvårdarna')
# ('var', 'en', 'godsinnade')
# ('var', 'en', 'grönsakshandlarna')
# ('var', 'en', 'gästhusen')
# ('var', 'en', 'gråtomuren')
# ('var', 'en', 'galleriet')
# ('var', 'en', 'gråbrun')
# ('var', 'en', 'gördeln')
# ('var', 'en', 'gulbränd')
# ('var', 'en', 'gehennas')
# ('var', 'en', 'grubblande')
# ('var', 'en', 'grönsaker')
# ('var', 'en', 'gunhilds')
# ('var', 'en', 'glimmerkornen')
# ('var', 'en', 'gathundarna')
# ('var', 'en', 'guldfärgadt')
# ('var', 'en', 'gordonister')
# ('var', 'en', 'guvernören')
# ('var', 'en', 'gifvas')
# ('var', 'en', 'grundläggningen')
# ('var', 'en', 'gulgrått')
# ('var', 'en', 'grankottar')
# ('var', 'en', 'gullilja')
# ('var', 'en', 'garnier')
# ('var', 'en', 'grafkullarna')
# ('var', 'en', 'guldskimrande')
# ('var', 'en', 'gunnarsson')
# ('var', 'en', 'grafhäll')
# ('var', 'en', 'grästorfva')
# ('var', 'en', 'gamar')
# ('var', 'en', 'gretas')
# ('var', 'en', 'graffyllda')
# ('var', 'en', 'genomlefvat')
# ('var', 'en', 'granatträd')
# ('var', 'en', 'genomlefva')
# ('var', 'en', 'gördlar')
# ('var', 'en', 'gråaktiga')
# ('var', 'en', 'grannkvinna')
# ('var', 'en', 'gropens')
# ('var', 'en', 'giftermålsförslag')
# ('var', 'en', 'gråsprängdt')
# ('var', 'en', 'grönmålad')
# ('var', 'en', 'gosch')
# ('var', 'en', 'generad')
# ('var', 'en', 'guldsmedsverkstad')
# ('var', 'en', 'graföppnarna')
# ('var', 'en', 'gräfvandet')
# ('var', 'en', 'grafhällar')
# ('var', 'en', 'gudomlighet')
# ('var', 'en', 'glädjes')
# ('var', 'en', 'granriset')
# ('var', 'en', 'getmjölk')
# ('var', 'en', 'gömdes')
# ('var', 'en', 'grufligt')
# ('var', 'en', 'gunnarsbybacken')
# ('var', 'en', 'guldsmedsbutiken')
# ('var', 'en', 'gatlyktor')
# ('var', 'en', 'guldsmedsbutik')
# ('var', 'en', 'glasdörr')
# ('var', 'en', 'guldsmeden')
# ('var', 'en', 'guldsmedens')
# ('var', 'en', 'generade')
# ('var', 'en', 'guldsaker')
# ('var', 'en', 'goddagar')
# ('var', 'en', 'grogg')
# ('var', 'en', 'grepkorgar')
# ('var', 'en', 'grepkorgarna')
# ('var', 'en', 'gudliga')
# ('var', 'en', 'gnabbades')
# ('var', 'en', 'godmorgon')
# ('var', 'en', 'gammelfrua')
# ('var', 'en', 'getstig')
# ('var', 'en', 'genomdrogos')
# ('var', 'en', 'gasten')
# ('var', 'en', 'gårdskontor')
# ('var', 'en', 'gammelfruas')
# ('var', 'en', 'gårdskontoret')
# ('var', 'en', 'gråtfärdiga')
# ('var', 'en', 'gåsslakt')
# ('var', 'en', 'gåshonan')
# ('var', 'en', 'gevalt')
# ('var', 'en', 'gastarna')
# ('var', 'en', 'gångare')
# ('var', 'en', 'granskogsmörkret')
# ('var', 'en', 'gubevars')
# ('var', 'en', 'govilligt')
# ('var', 'en', 'griller')
# ('var', 'en', 'gråbena')
# ('var', 'en', 'glupska')
# ('var', 'en', 'gråstenar')
# ('var', 'en', 'grin')
# ('var', 'en', 'geck')
# ('var', 'en', 'gömmas')
# ('var', 'en', 'grundpelaren')
# ('var', 'en', 'giftaslusten')
# ('var', 'en', 'gårdsrättarn')
# ('var', 'en', 'gårdsfolke')
# ('var', 'en', 'glae')
# ('var', 'en', 'gräddsnipa')
# ('var', 'en', 'gerda')
# ('var', 'en', 'gårn')
# ('var', 'en', 'gurkor')
# ('var', 'en', 'guldpapper')
# ('var', 'en', 'grannlåten')
# ('var', 'en', 'guldbrosch')
# ('var', 'en', 'guldkedja')
# ('var', 'en', 'guldarmband')
# ('var', 'en', 'guldur')
# ('var', 'en', 'gratulerande')
# ('var', 'en', 'gästabudsbrådskan')
# ('var', 'en', 'gardeslöjtnant')
# ('var', 'en', 'gatuvimlet')
# ('var', 'en', 'grossörernas')
# ('var', 'en', 'glättiga')
# ('var', 'en', 'gloriesken')
# ('var', 'en', 'gunnarsby')
# ('var', 'en', 'gästgivaregård')
# ('var', 'en', 'giktknölarna')
# ('var', 'en', 'godsaker')
# ('var', 'en', 'geijer')
# ('var', 'en', 'giktstela')
# ('var', 'en', 'grytlock')
# ('var', 'en', 'gnälliga')
# ('var', 'en', 'grindstolparna')
# ('var', 'en', 'grundstenarna')
# ('var', 'en', 'grundläggarna')
# ('var', 'en', 'gesäller')
# ('var', 'en', 'grundläggningsarbete')
# ('var', 'en', 'gårdsjö')
# ('var', 'en', 'gullgosse')
# ('var', 'en', 'gängorna')
# ('var', 'en', 'göteborgs')
# ('var', 'en', 'gräsmatta')
# ('var', 'en', 'gullvivor')
# ('var', 'en', 'gulröda')
# ('var', 'en', 'gäld')
# ('var', 'en', 'generationers')
# ('var', 'en', 'gymnasisterna')
# ('var', 'en', 'grundliga')
# ('var', 'en', 'gräddade')
# ('var', 'en', 'gorån')
# ('var', 'en', 'garvar')
# ('var', 'en', 'garvarn')
# ('var', 'en', 'golvtiljorna')
# ('var', 'en', 'gräddrosor')
# ('var', 'en', 'guvernant')
# ('var', 'en', 'grushåla')
# ('var', 'en', 'grenig')
# ('var', 'en', 'granstubbe')
# ('var', 'en', 'gossarnas')
# ('var', 'en', 'gikt')
# ('var', 'en', 'gubbstackarn')
# ('var', 'en', 'gammel')
# ('var', 'en', 'guldpengar')
# ('var', 'en', 'guldskogar')
# ('var', 'en', 'gårdsjön')
# ('var', 'en', 'gårdsjöfiskarna')
# ('var', 'en', 'gädda')
# ('var', 'en', 'gemen')
# ('var', 'en', 'gudskelov')
# ('var', 'en', 'gårdsjöfiskarn')
# ('var', 'en', 'grädda')
# ('var', 'en', 'glansnummer')
# ('var', 'en', 'generalrepetitionen')
# ('var', 'en', 'gårdsjöborna')
# ('var', 'en', 'georgina')
# ('var', 'en', 'gårdsjövagnarna')
# ('var', 'en', 'gudomligheterna')
# ('var', 'en', 'gudarna')
# ('var', 'en', 'genomstrålas')
# ('var', 'en', 'gensvar')
# ('var', 'en', 'genkärlek')
# ('var', 'en', 'genomströmmar')
# ('var', 'en', 'gärdesgårdar')
# ('var', 'en', 'gödselstäderna')
# ('var', 'en', 'gångande')
# ('var', 'en', 'glattsliten')
# ('var', 'en', 'gnedo')
# ('var', 'en', 'gästgivargårdar')
# ('var', 'en', 'gästvänner')
# ('var', 'en', 'gulaktiga')
# ('var', 'en', 'grisögon')
# ('var', 'en', 'gudsförsmädelse')
# ('var', 'en', 'gudsförnekare')
# ('var', 'en', 'gudstro')
# ('var', 'en', 'gungats')
# ('var', 'en', 'gammaldagskläder')
# ('var', 'en', 'gudsförnekande')
# ('var', 'en', 'grävd')
# ('var', 'en', 'grenrika')
# ('var', 'en', 'glattbladiga')
# ('var', 'en', 'gäddor')
# ('var', 'en', 'guldstrimmigt')
# ('var', 'en', 'guldspänne')
# ('var', 'en', 'granrötterna')
# ('var', 'en', 'grönare')
# ('var', 'en', 'granroten')
# ('var', 'en', 'gästabudsbordet')
# ('var', 'en', 'giller')
# ('var', 'en', 'grundval')
# ('var', 'en', 'genomfarits')
# ('var', 'en', 'gräshoppa')
# ('var', 'en', 'gravställena')
# ('var', 'en', 'grånad')
# ('var', 'en', 'gethjordar')
# ('var', 'en', 'gengångaren')
# ('var', 'en', 'gravhögen')
# ('var', 'en', 'gissla')
# ('var', 'en', 'gisslande')
# ('var', 'en', 'gravlagt')
# ('var', 'en', 'görande')
# ('var', 'en', 'galnare')
# ('var', 'en', 'gräsklädd')
# ('var', 'en', 'gräsgrön')
# ('var', 'en', 'gråstensdörr')
# ('var', 'en', 'genomilades')
# ('var', 'en', 'grundmur')
# ('var', 'en', 'gudsfreden')
# ('var', 'en', 'gärdena')
# ('var', 'en', 'grandungen')
# ('var', 'en', 'grovstammiga')
# ('var', 'en', 'granstam')
# ('var', 'en', 'gästabudsrummen')
# ('var', 'en', 'granrisat')
# ('var', 'en', 'gammalkloka')
# ('var', 'en', 'galgen')
# ('var', 'en', 'grupperna')
# ('var', 'en', 'guldsmedsgesällen')
# ('var', 'en', 'guldsmedsgesäll')
# ('var', 'en', 'gudlöse')
# ('var', 'en', 'genomila')
# ('var', 'en', 'giftklumpen')
# ('var', 'en', 'gesanten')
# ('var', 'en', 'genomlevats')
# ('var', 'en', 'genomlevdes')
# ('var', 'en', 'genomfara')
# ('var', 'en', 'gräsbeväxt')
# ('var', 'en', 'giljat')
# ('var', 'en', 'glädjelösheten')
# ('var', 'en', 'gubbar')
# ('var', 'en', 'guldbroschen')
# ('var', 'en', 'guldkedjan')
# ('var', 'en', 'giftasaffärer')
# ('var', 'en', 'gesällen')
# ('var', 'en', 'grannkvinnan')
# ('var', 'en', 'gadden')
# ('var', 'en', 'giftströmmen')
# ('var', 'en', 'genomskådade')
# ('var', 'en', 'gesäll')
# ('var', 'en', 'gitarrerna')
# ('var', 'en', 'gatvisa')
# ('var', 'en', 'gatvisan')
# ('var', 'en', 'glödröd')
# ('var', 'en', 'godtemplartåget')
# ('var', 'en', 'grodan')
# ('var', 'en', 'guldbaggar')
# ('var', 'en', 'gungan')
# ('var', 'en', 'glåporden')
# ('var', 'en', 'gudsförsmädaren')
# ('var', 'en', 'gam')
# ('var', 'en', 'gångaren')
# ('var', 'en', 'grane')
# ('var', 'en', 'görans')
# ('var', 'en', 'gny')
# ('var', 'en', 'gömstället')
# ('var', 'en', 'gravskriften')
# ('var', 'en', 'glaslådor')
# ('var', 'en', 'granitblock')
# ('var', 'en', 'gemenskap')
# ('var', 'en', 'gråtes')
# ('var', 'en', 'gråtas')
# ('var', 'en', 'gammalmodig')
# ('var', 'en', 'gravranden')
# ('var', 'en', 'genomstråla')
# ('var', 'en', 'grönsakerna')
# ('var', 'en', 'guldgult')
# ('var', 'en', 'gracchernas')
# ('var', 'en', 'gräsligt')
# ('var', 'en', 'gendarmerna')
# ('var', 'en', 'grönögd')
# ('var', 'en', 'grundstötningen')
# ('var', 'en', 'gotland')
# ('var', 'en', 'gångstigar')
# ('var', 'en', 'gästgivarens')
# ('var', 'en', 'gruvdelar')
# ('var', 'en', 'granhäckar')
# ('var', 'en', 'gräsvippor')
# ('var', 'en', 'gasellögon')
# ('var', 'en', 'genomsvävas')
# ('var', 'en', 'greklands')
# ('var', 'en', 'gycklade')
# ('var', 'en', 'grandezza')
# ('var', 'en', 'gallerier')
# ('var', 'en', 'gulsvarta')
# ('var', 'en', 'gule')
# ('var', 'en', 'gulröde')
# ('var', 'en', 'giftkroken')
# ('var', 'en', 'genombedrövad')
# ('var', 'en', 'gulleborg')
# ('var', 'en', 'gråvädersdag')
# ('var', 'en', 'gudmor')
# ('var', 'en', 'gudföräldrarna')
# ('var', 'en', 'gudmodern')
# ('var', 'en', 'gudfolk')
# ('var', 'en', 'grannmoran')
# ('var', 'en', 'gråsvart')
# ('var', 'en', 'gungas')
# ('var', 'en', 'gullas')
# ('var', 'en', 'granträd')
# ('var', 'en', 'grannhustru')
# ('var', 'en', 'gåspennorna')
# ('var', 'en', 'greppa')
# ('var', 'en', 'glasögona')
# ('var', 'en', 'glasögonsfodralet')
# ('var', 'en', 'grannklätt')
# ('var', 'en', 'gratulationsvers')
# ('var', 'en', 'grangrenarna')
# ('var', 'en', 'gallrade')
# ('var', 'en', 'guldkors')
# ('var', 'en', 'gränsröse')
# ('var', 'en', 'gökunge')
# ('var', 'en', 'gransuset')
# ('var', 'en', 'gungfly')
# ('var', 'en', 'gyttjan')
# ('var', 'en', 'giktfeber')
# ('var', 'en', 'gentemot')
# ('var', 'en', 'gapskratta')
# ('var', 'en', 'grannlåt')
# ('var', 'en', 'grusad')
# ('var', 'en', 'grusvägen')
# ('var', 'en', 'glader')
# ('var', 'en', 'gullkronan')
# ('var', 'en', 'gullsabeln')
# ('var', 'en', 'gulläpplena')
# ('var', 'en', 'gallade')
# ('var', 'en', 'gen')
# ('var', 'en', 'granntyckt')
# ('var', 'en', 'generalskorna')
# ('var', 'en', 'grannklädda')
# ('var', 'en', 'guldmaljong')
# ('var', 'en', 'grannfolk')
# ('var', 'en', 'guldmaljongen')
# ('var', 'en', 'grannstugan')
# ('var', 'en', 'gunnarssons')
# ('var', 'en', 'glasskärvor')
# ('var', 'en', 'gäldenär')
# ('var', 'en', 'grindhålet')
# ('var', 'en', 'guldpappersbit')
# ('var', 'en', 'gästgivargår')
# ('var', 'en', 'guldpappersbiten')
# ('var', 'en', 'gamlingarna')
# ('var', 'en', 'grågul')
# ('var', 'en', 'gulnad')
# ('var', 'en', 'gullborg')
# ('var', 'en', 'gnällig')
# ('var', 'en', 'guldkronan')
# ('var', 'en', 'guldtronen')
# ('var', 'en', 'guldklädda')
# ('var', 'en', 'godsmagasinet')
# ('var', 'en', 'gottgörelse')

# %%
current_word_predictions_2
# Out:
# ['gammal', 'god', 'gång', 'ganska', 'grann']

# %% [markdown]
# ## Checked answers

# %% [markdown]
# The system will check these answers: `(perplexity_unigrams, perplexity_bigrams, current_word_predictions_1, next_word_predictions, current_word_predictions_2)`

# %%
(perplexity_unigrams, perplexity_bigrams, current_word_predictions_1, next_word_predictions, current_word_predictions_2)
# Out:
# (423,
#  None,
#  ['det', 'de', 'den', 'detta', 'denna'],
#  ['stor', 'liten', 'gammal', 'god', 'sådan'],
#  ['gammal', 'god', 'gång', 'ganska', 'grann'])

# %% [markdown]
# ## Submission

# %% [markdown]
# When you have written all the code and run all the cells, fill in your ID and as well as the name of the notebook.

# %%
STIL_ID = ["da20exampl-s", "ad02exampl-z"] # Write your stil ids as a list
CURRENT_NOTEBOOK_PATH = os.path.join(os.getcwd(), 
                                     "2-language_models_solution.ipynb") # Write the name of your notebook

# %% [markdown]
# The submission code will send your answer. It consists of the perplexities and predictions.

# %%
ANSWER = str((perplexity_unigrams, perplexity_bigrams, current_word_predictions_1, next_word_predictions, current_word_predictions_2))
ANSWER

# %% [markdown]
# Now the moment of truth:
# 1. Save your notebook and
# 2. Run the cells below

# %%
SUBMISSION_NOTEBOOK_PATH = CURRENT_NOTEBOOK_PATH + ".submission.bz2"

# %%
ASSIGNMENT = 2
API_KEY = "f581ba347babfea0b8f2c74a3a6776a7"

# Copy and compress current notebook
with bz2.open(SUBMISSION_NOTEBOOK_PATH, mode="wb") as fout:
    with open(CURRENT_NOTEBOOK_PATH, "rb") as fin:
        fout.write(fin.read())

# %%
res = requests.post("https://vilde.cs.lth.se/edan20checker/submit", 
                    files={"notebook_file": open(SUBMISSION_NOTEBOOK_PATH, "rb")}, 
                    data={
                        "stil_id": STIL_ID,
                        "assignment": ASSIGNMENT,
                        "answer": ANSWER,
                        "api_key": API_KEY,
                    },
                   verify=True)

# from IPython.display import display, JSON
res.json()

# %% [markdown]
# ## Reading

# %% [markdown]
# <p>As an application of n-grams, execute the Jupyter notebook by Peter Norvig <a
#         href="http://nbviewer.jupyter.org/url/norvig.com/ipython/How%20to%20Do%20Things%20with%20Words.ipynb">
#     here</a>. Just run all the cells and be sure that you understand the code.
#     You will find the data <a href="http://norvig.com/ngrams/">here</a>.</p>
# <p>In your report, you will also describe one experiment with a long string of words
#     your will create yourself or copy from a text you like. You will remove all the punctuation and
#     white spaces from this string. Set this string in lowercase letters.</p>
# <p>You will just add a cell at the end of Sect. 7 in Norvig's notebook, where you will use your string and
#     run the notebook cell with the <tt>segment()</tt> and <tt>segment2()</tt> functions. </p>
# <p>You will comment the segmentation results you obtain with unigram and bigram models.
# </p>
